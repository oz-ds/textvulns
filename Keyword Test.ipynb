# %% [markdown]
# # Find vulnerabilities using Keyword based classifier

# %%
import vulns_common
from sklearn.utils import shuffle

vulns_common.download_nvd_vulns_json()
nvd_vulns = vulns_common.load_nvd_vulns_json('data/nvdcve-1.0-*.json')
print('Vulnerability descriptions: ' + str(len(nvd_vulns)))
cpe_names = vulns_common.compile_cpe_names(nvd_vulns)
print('Vulnerable product names:'+str(len(cpe_names)))
vuln_data = shuffle(nvd_vulns, n_samples=4000)
print('Vulnerability learning data: ' + str(len(vuln_data)))
# Out:
# Vulnerability descriptions: 32963
# Vulnerable product names:9176
# Vulnerability learning data: 4000

# %%
import pandas as pd

vuln_descs = []
for d in vuln_data:
    if not d[1].startswith('** REJECT'):#a few descriptions are rejected by nvd
        vuln_descs.append(d[1])

reports = pd.read_excel('data/sec_issues_edit.xlsx')
reports = reports.loc[(reports['security']==1)]
reports['security'] = reports['security'].values.astype(bool)
reports['report'] = reports['report'].values.astype(str)
print('Manually labeled vulnerability dataset: '+ str(len(reports)))
print('Mixed with non-security issues')
mixed = vulns_common.get_mixed_dataset(reports['report'], 1000)
print(mixed.shape)
mixed.head(10)
# Out:
# Manually labeled vulnerability dataset: 148
# Mixed with non-security issues
# (1148, 2)
#                                                   report  security
# 23298  Issue 24548 : Downloads Page is Blank (NOT usi...        -1
# 8      dblook displays message keys instead of their ...        -1
# 118    Issue 12027 : Memory corruption on dragging fi...         1
# 972    SJMS component throws class cast error when us...        -1
# 387    o.a.wicket.ng.** Resource related classes don'...        -1
# 309    Implement SSL/TLS communication between client...         1
# 787    ComponentFeedbackPanel broken under Wicket 6.0...        -1
# 172    Pipeline could change the MEP unintended   Whe...        -1
# 7360   Issue 7712 : Make FileStream use IOBuffer &lsa...        -1
# 598    Convert altertable.sql to JUnit   Converting a...        -1

# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from nltk import ngrams
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction import text
import time

class LemmaCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        self.stemmer = WordNetLemmatizer()
        analyzer = super(CountVectorizer, self).build_analyzer()
        return lambda doc: (analyzer(' '.join([self.stemmer.lemmatize(word) for word in doc.split(' ')])))  

class StemmedCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        self.stemmer = SnowballStemmer("english")
        analyzer = super(CountVectorizer, self).build_analyzer()

        return lambda doc: (analyzer(' '.join([self.stemmer.stem(word) for word in doc.split(' ')])))

class KeywordStemClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, min_ngrams=2, max_ngrams=2):
        self.min_ngrams = min_ngrams
        self.max_ngrams = max_ngrams
        unwanted_words = ['issue','defect','bug','fault','flaw','mistake','error','version','system','because','before','disputed']
        stop_words = text.ENGLISH_STOP_WORDS#.union(cpe_names)
        stop_words = stop_words.union(unwanted_words)
        self.vectorizer = StemmedCountVectorizer(stop_words=stop_words,
                                                 lowercase=True,
                                                 ngram_range=(min_ngrams, max_ngrams), 
                                                 min_df=1,
                                                 token_pattern=r'(?u)\b\w*[a-zA-Z]{3,}\w*\b')

    def fit(self, raw_documents, y=None):
        self.vectorizer.fit(raw_documents)

        return self
    
    def predict(self, raw_documents, y=None):
        assert (len(self.vectorizer.vocabulary_) > 0), "You must call fit() before predicting data!"
        scores = self.score(raw_documents)
        
        predictions = []
        for count in scores:
            if count >= 2:#at least two vulnerability n-grams classified as security related
                predictions.append(1)
            else:
                predictions.append(-1)
        
        return np.array(predictions)   
    
    def word_grams(self, words, min, max):
        s = []
        for n in range(min, max+1):
            for ngram in ngrams(words, n):
                s.append(' '.join(str(i) for i in ngram))
        return s
    
    def _score_single(self, tokens):
        count= 0
        for index, token in enumerate(tokens):
            if token in self.vectorizer.vocabulary_:
                count = count + 1
        return count
        
    def score(self, raw_documents, y=None):
        assert (len(self.vectorizer.vocabulary_) > 0), "You must call fit() before scoring data!"
        stemmer = SnowballStemmer("english")
        
        scores = []
        for index, row in enumerate(raw_documents):
            stems = []
            for word in row.split():
                stems.append(stemmer.stem(word))
            tokens = self.word_grams(stems, self.min_ngrams, self.max_ngrams)
            count = self._score_single(tokens)
            scores.append(count)
        
        return np.array(scores)        
    
nfold = 10

print('Mixed dataset: '+ str(len(mixed)))
c = KeywordStemClassifier()
#get a new learning data before the fit method
vuln_data = shuffle(nvd_vulns, n_samples=4000)
vuln_descs = []
for d in vuln_data:
    if not d[1].startswith('** REJECT'):#some descriptions are rejected by NVD
        vuln_descs.append(d[1])
c.fit(vuln_descs)
scores = []
t = time.time()
for i in range(nfold): #n-fold cross val score
    #get a new testing set
    mixed = vulns_common.get_mixed_dataset(reports['report'], 1000)  
    predicted = c.predict(mixed['report'])
    #score = f1_score(y_true=mixed['security'], y_pred=predicted, average='micro')
    score = roc_auc_score(y_true=mixed['security'], y_score=predicted, average='micro')
    scores.append(score)
    
scores = np.array(scores)
print(str(nfold)+'-fold cross validated score:' + str(scores.mean()))
print('Time taken: ' + str(round(time.time() - t, 1)) + 's')
print("Vocabulary items:" + str(len(c.vectorizer.vocabulary_)))
# Out:
# Mixed dataset: 1148
# 10-fold cross validated score:0.7520364864864865
# Time taken: 144.0s
# Vocabulary items:42035

# %%
# some score and predict tests
p = shuffle(vuln_descs, n_samples=1)
print(p[0])
print(c.score(p))
print(c.predict(p))

p = reports.sample(n=1)
print(p['report'].iloc[0])
print(c.score(p['report']))
print(c.predict(p['report']))

p = mixed.sample(n=1)
print(p['report'].iloc[0])
print(p['security'].iloc[0])
print(c.score(p['report']))
print(c.predict(p['report']))
# Out:
# SecurEnvoy SecurMail before 9.2.501 allows remote authenticated users to read arbitrary e-mail messages via the option1 parameter in a reply action to secmail/getmessage.exe.
# [8]
# [1]
# Blind SQL Injection SQL injection (SQLi) refers to an injection attack wherein an attacker can execute malicious SQL statements that control a web application's database server. URL encoded POST input enddate was set to f14QC2St'; waitfor delay '0:0:0' --
# [10]
# [1]
# HDFS Service Check failed (as designed) but took 10 mins to fail   After I had a cluster up and running successfully  but manually turned HDFS Safe Mode ON by running:hdfs dfsadmin -safemode enter.HDFS Execute Check failed due to Puppet timeout after 10 minutes.It should have failed quicker since task timeout is 10 minutes on server.
# -1
# [1]
# [-1]

# %%
## how it finds manually labeled vulnerability issues

# %%
import pandas as pd
reports = pd.read_excel('data/sec_issues_edit.xlsx')
reports = reports.loc[(reports['security']==1)]
reports['security'] = reports['security'].values.astype(bool)
reports['report'] = reports['report'].values.astype(str)
print('Manually labeled vulnerability dataset: '+ str(len(reports)))
predicted = c.predict(reports['report'])
vulns_common.print_vulns_metrics(reports['security'], predicted)
# Out:
# Manually labeled vulnerability dataset: 148
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         0
#            1       1.00      0.72      0.84       148
#
#    micro avg       0.72      0.72      0.72       148
#    macro avg       0.50      0.36      0.42       148
# weighted avg       1.00      0.72      0.84       148
#
# TN=0, FP=0, FN=41, TP=107
# C:\Users\ossi.jormakka\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
## How it finds from the learning set

# %%
print('Vulnerability learning dataset:'+str(len(vuln_descs)))
predicted = c.predict(vuln_descs)
vulns_common.print_vulns_metrics([1]*len(vuln_descs), predicted)
# Out:
# Vulnerability learning dataset:3884
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         0
#            1       1.00      0.95      0.97      3884
#
#    micro avg       0.95      0.95      0.95      3884
#    macro avg       0.50      0.47      0.49      3884
# weighted avg       1.00      0.95      0.97      3884
#
# TN=0, FP=0, FN=195, TP=3689

# %%
# some vulnerability words in vocabulary
c.vectorizer.vocabulary_
# Out:
# {'minttoken function': 23674,
#  'function smart': 15980,
#  'smart contract': 34710,
#  'contract implement': 8357,
#  'implement eststoken': 18113,
#  'eststoken ethereum': 13241,
#  'ethereum token': 13259,
#  'token integ': 37065,
#  'integ overflow': 19274,
#  'overflow allow': 26076,
#  'allow owner': 1818,
#  'owner contract': 26231,
#  'contract set': 8362,
#  'set balanc': 34017,
#  'balanc arbitrari': 3949,
#  'arbitrari user': 2749,
#  'user ani': 38843,
#  'ani value': 2132,
#  'fork cms': 15457,
#  'cms allow': 6748,
#  'allow store': 1868,
#  'store xss': 35733,
#  'xss private': 41833,
#  'private set': 28953,
#  'set facebook_admin_id': 34030,
#  'facebook_admin_id paramet': 14298,
#  'paramet aka': 26547,
#  'aka admin': 1553,
#  'admin ids': 1035,
#  'ids input': 17822,
#  'input facebook': 18928,
#  'facebook section': 14296,
#  'vulner allow': 40184,
#  'allow remot': 1841,
#  'remot attack': 30992,
#  'attack disclos': 3178,
#  'disclos sensit': 11183,
#  'sensit inform': 33225,
#  'inform vulner': 18670,
#  'vulner instal': 40382,
#  'instal foxit': 19095,
#  'foxit reader': 15579,
#  'reader user': 30478,
#  'user interact': 38973,
#  'interact requir': 19402,
#  'requir exploit': 31422,
#  'exploit vulner': 14019,
#  'vulner target': 40634,
#  'target visit': 36509,
#  'visit malici': 40045,
#  'malici page': 22612,
#  'page open': 26425,
#  'open malici': 25607,
#  'malici file': 22581,
#  'file specif': 14833,
#  'specif exist': 35135,
#  'exist converttopdf_x86': 13686,
#  'converttopdf_x86 dll': 8584,
#  'dll issu': 11640,
#  'issu result': 19940,
#  'result lack': 31806,
#  'lack proper': 20876,
#  'proper valid': 29629,
#  'valid user': 39437,
#  'user suppli': 39125,
#  'suppli data': 36185,
#  'data result': 9876,
#  'result read': 31831,
#  'read past': 30411,
#  'past end': 27031,
#  'end alloc': 12814,
#  'alloc object': 1707,
#  'object attack': 25151,
#  'attack leverag': 3252,
#  'leverag conjunct': 21347,
#  'conjunct vulner': 7867,
#  'vulner execut': 40295,
#  'execut arbitrari': 13441,
#  'arbitrari code': 2691,
#  'code context': 6832,
#  'context current': 8318,
#  'current process': 9556,
#  'process zdi': 29305,
#  'vulner cisco': 40237,
#  'cisco unifi': 6375,
#  'unifi communic': 37917,
#  'communic manag': 7294,
#  'manag allow': 22687,
#  'allow authenticated': 1735,
#  'authenticated remot': 3661,
#  'attack access': 3096,
#  'access sensit': 460,
#  'inform affect': 18554,
#  'affect vulner': 1455,
#  'vulner exist': 40298,
#  'exist becaus': 13673,
#  'becaus affect': 4086,
#  'affect softwar': 1428,
#  'softwar improp': 34900,
#  'improp valid': 18275,
#  'suppli search': 36200,
#  'search input': 32911,
#  'input attack': 18905,
#  'attack exploit': 3203,
#  'vulner send': 40580,
#  'send malici': 33171,
#  'malici request': 22620,
#  'request affect': 31225,
#  'affect success': 1436,
#  'success exploit': 36079,
#  'exploit allow': 13915,
#  'allow attack': 1732,
#  'attack retriev': 3328,
#  'retriev sensit': 31892,
#  'affect cisco': 1297,
#  'cisco ids': 6337,
#  'ids cscvf17644': 17764,
#  'php script': 27691,
#  'script mall': 32791,
#  'mall multi': 22661,
#  'multi languag': 24269,
#  'languag olx': 20899,
#  'olx clone': 25430,
#  'clone script': 6651,
#  'script xss': 32833,
#  'xss leav': 41798,
#  'leav comment': 21231,
#  'comment field': 7222,
#  'attack execut': 3200,
#  'code vulner': 6960,
#  'exist xfa': 13848,
#  'xfa execev': 41658,
#  'execev method': 13428,
#  'method button': 23491,
#  'button elements': 5206,
#  'elements issu': 12550,
#  'lack valid': 20886,
#  'valid exist': 39361,
#  'exist object': 13769,
#  'object prior': 25188,
#  'prior perform': 28861,
#  'perform oper': 27302,
#  'oper object': 25756,
#  'leverag vulner': 21371,
#  'execut code': 13459,
#  'vulner oracl': 40491,
#  'oracl applic': 25846,
#  'applic manag': 2563,
#  'manag compon': 22707,
#  'compon oracl': 7419,
#  'oracl busi': 25850,
#  'busi suit': 5199,
#  'suit subcomponent': 36140,
#  'subcomponent oracl': 35934,
#  'oracl diagnost': 25855,
#  'diagnost interfaces': 10935,
#  'interfaces support': 19531,
#  'support affect': 36205,
#  'affect easili': 1315,
#  'easili exploit': 12320,
#  'allow unauthent': 1880,
#  'unauthent attack': 37757,
#  'attack network': 3275,
#  'network access': 24588,
#  'access http': 336,
#  'http compromis': 17379,
#  'compromis oracl': 7476,
#  'applic manager': 2564,
#  'manager success': 22852,
#  'success attack': 36075,
#  'attack vulner': 3382,
#  'vulner result': 40567,
#  'result unauthor': 31851,
#  'unauthor access': 37786,
#  'access critic': 284,
#  'critic data': 9330,
#  'data complet': 9747,
#  'complet access': 7350,
#  'access oracl': 402,
#  'manag access': 22682,
#  'access data': 286,
#  'data cvss': 9757,
#  'cvss base': 9630,
#  'base score': 4030,
#  'score confidenti': 32721,
#  'confidenti impacts': 7644,
#  'impacts cvss': 18046,
#  'cvss vector': 9632,
#  'vector cvss': 39675,
#  'teardownclientinterfac wificondcontrol': 36580,
#  'wificondcontrol java': 41169,
#  'java possibl': 20095,
#  'possibl use': 28441,
#  'use free': 38540,
#  'free improp': 15694,
#  'improp locking': 18256,
#  'locking lead': 22028,
#  'lead local': 21107,
#  'local escal': 21943,
#  'escal privileg': 13167,
#  'privileg addit': 28958,
#  'addit execut': 872,
#  'execut privileg': 13532,
#  'privileg needed': 29027,
#  'needed user': 24514,
#  'interact need': 19397,
#  'need exploitation': 24496,
#  'exploitation product': 14026,
#  'product android': 29348,
#  'android versions': 2033,
#  'versions android': 39782,
#  'android android': 1989,
#  'vulner batch': 40210,
#  'batch provis': 4067,
#  'provis featur': 29868,
#  'featur cisco': 14406,
#  'cisco prime': 6355,
#  'prime collabor': 28723,
#  'collabor provis': 7013,
#  'provis tool': 29873,
#  'tool allow': 37094,
#  'attack overwrit': 3287,
#  'overwrit file': 26206,
#  'file root': 14815,
#  'root vulner': 32119,
#  'vulner lack': 40415,
#  'lack input': 20869,
#  'input valid': 18978,
#  'valid paramet': 39402,
#  'paramet batchfilenam': 26553,
#  'batchfilenam directory': 4068,
#  'directory attack': 11122,
#  'vulner manipul': 40437,
#  'manipul paramet': 22878,
#  'paramet batch': 26552,
#  'batch action': 4065,
#  'action file': 703,
#  'file function': 14688,
#  'function cisco': 15833,
#  'ids cscvd61766': 17743,
#  'inform disclosur': 18580,
#  'disclosur vulner': 11232,
#  'exist affect': 13658,
#  'affect open': 1375,
#  'open enclav': 25596,
#  'enclav sdk': 12757,
#  'sdk improp': 32860,
#  'improp handl': 18250,
#  'handl object': 16732,
#  'object memory': 25184,
#  'memory aka': 23315,
#  'aka open': 1606,
#  'sdk inform': 32861,
#  'disclosur vulnerability': 11233,
#  'centos webpanel': 5753,
#  'webpanel com': 41040,
#  'com aka': 7038,
#  'aka cwp': 1569,
#  'cwp cento': 9653,
#  'cento web': 5752,
#  'web panel': 40945,
#  'panel file': 26517,
#  'file directori': 14651,
#  'directori inform': 11085,
#  'inform exposur': 18591,
#  'exposur filemanag': 14120,
#  'filemanag allow': 14892,
#  'attack enumer': 3196,
#  'enumer user': 13064,
#  'user check': 38871,
#  'check activ': 6090,
#  'activ user': 775,
#  'user applic': 38845,
#  'applic read': 2590,
#  'read tmp': 30441,
#  'tmp login': 37031,
#  'login log': 22164,
#  'attachecas ver': 3086,
#  'ver earlier': 39715,
#  'earlier allow': 12199,
#  'allow arbitrari': 1730,
#  'arbitrari script': 2738,
#  'script execut': 32775,
#  'execut unspecifi': 13572,
#  'unspecifi vectors': 38087,
#  'disput samsung': 11600,
#  'samsung xcover': 32504,
#  'xcover devic': 41646,
#  'devic becom': 10683,
#  'becom temporarili': 4223,
#  'temporarili inoper': 36673,
#  'inoper becaus': 18893,
#  'becaus unprotect': 4197,
#  'unprotect intent': 38030,
#  'intent containerag': 19380,
#  'containerag application': 8214,
#  'application example': 2633,
#  'example victim': 13366,
#  'victim becom': 39856,
#  'becom stuck': 4222,
#  'stuck launcher': 35863,
#  'launcher secur': 20989,
#  'secur folder': 32996,
#  'folder locked': 15337,
#  'locked note': 22024,
#  'note research': 24992,
#  'research mention': 31459,
#  'mention samsung': 23330,
#  'samsung secur': 32501,
#  'secur team': 33043,
#  'team consid': 36569,
#  'consid issu': 7992,
#  'issu littl': 19920,
#  'littl secur': 21833,
#  'secur impact': 33003,
#  'rtcmulticonnection cli': 32233,
#  'cli signal': 6503,
#  'signal implement': 34368,
#  'implement rtcmulticonnection': 18170,
#  'rtcmulticonnection multi': 32234,
#  'multi sess': 24273,
#  'sess manager': 33925,
#  'manager rtcmulticonnection': 22851,
#  'cli vulner': 6507,
#  'vulner directori': 40273,
#  'directori travers': 11111,
#  'travers attack': 37330,
#  'access filesystem': 317,
#  'filesystem place': 14952,
#  'place url': 27879,
#  'issu discov': 19895,
#  'discov typesett': 11498,
#  'typesett suffer': 37641,
#  'suffer host': 36100,
#  'host header': 17206,
#  'header inject': 16956,
#  'inject vulnerability': 18867,
#  'vulnerability use': 40758,
#  'use attack': 38425,
#  'attack malici': 3263,
#  'malici user': 22644,
#  'user poison': 39056,
#  'poison web': 28169,
#  'web cach': 40915,
#  'cach perform': 5344,
#  'perform advanc': 27262,
#  'advanc password': 1226,
#  'password reset': 26992,
#  'reset attack': 31469,
#  'attack trigger': 3362,
#  'trigger arbitrari': 37412,
#  'user direction': 38913,
#  'incorrect handl': 18445,
#  'handl confus': 16676,
#  'confus charact': 7847,
#  'charact url': 6071,
#  'url formatt': 38330,
#  'formatt googl': 15510,
#  'googl chrome': 16437,
#  'chrome prior': 6238,
#  'prior allow': 28776,
#  'attack perform': 3291,
#  'perform domain': 27286,
#  'domain spoof': 11865,
#  'spoof idn': 35264,
#  'idn homograph': 17707,
#  'homograph craft': 17164,
#  'craft domain': 8921,
#  'uipath orchestr': 37719,
#  'orchestr befor': 25897,
#  'befor allow': 4241,
#  'allow csv': 1760,
#  'csv injection': 9521,
#  'injection relat': 18882,
#  'relat audit': 30829,
#  'audit export': 3504,
#  'export robot': 14063,
#  'robot log': 32023,
#  'log export': 22061,
#  'export transact': 14064,
#  'transact log': 37255,
#  'export features': 14057,
#  'openframe glsview': 25645,
#  'glsview openfram': 16369,
#  'openfram extens': 25644,
#  'extens add': 14184,
#  'add support': 851,
#  'support shader': 36228,
#  'shader glslviewer': 34166,
#  'glslviewer openframe': 16367,
#  'glsview download': 16368,
#  'download binari': 11944,
#  'binari resourc': 4639,
#  'resourc http': 31528,
#  'http leav': 17400,
#  'leav vulner': 21237,
#  'vulner mitm': 40450,
#  'mitm attacks': 23780,
#  'attacks possibl': 3416,
#  'possibl caus': 28382,
#  'caus remot': 5656,
#  'remot code': 31003,
#  'code execut': 6852,
#  'execut rce': 13537,
#  'rce swap': 30292,
#  'swap request': 36282,
#  'request binari': 31239,
#  'binari attack': 4625,
#  'attack control': 3151,
#  'control binari': 8392,
#  'network posit': 24667,
#  'posit user': 28365,
#  'user remot': 39081,
#  'remot server': 31040,
#  'gradl enterpris': 16475,
#  'enterpris befor': 12974,
#  'befor build': 4258,
#  'build cach': 5120,
#  'cach node': 5342,
#  'node did': 24844,
#  'did store': 10959,
#  'store credenti': 35698,
#  'credenti rest': 9289,
#  'rest encrypt': 31635,
#  'encrypt format': 12789,
#  'cross sit': 9353,
#  'sit script': 34537,
#  'xss vulner': 41871,
#  'vulner notif': 40474,
#  'notif center': 25006,
#  'center synolog': 5749,
#  'synolog calendar': 36354,
#  'calendar befor': 5375,
#  'remot authent': 30994,
#  'authent user': 3645,
#  'user inject': 38965,
#  'inject arbitrari': 18775,
#  'arbitrari web': 2752,
#  'web script': 40956,
#  'script html': 32782,
#  'html titl': 17362,
#  'titl parameter': 36971,
#  'ibm user': 17594,
#  'user restor': 39088,
#  'restor user': 31687,
#  'user profil': 39067,
#  'profil rstusrprf': 29472,
#  'rstusrprf configur': 32230,
#  'configur mirror': 7750,
#  'mirror user': 23683,
#  'profil elev': 29460,
#  'elev privileg': 12557,
#  'privileg caus': 28973,
#  'caus incorrect': 5604,
#  'incorrect process': 18464,
#  'process dure': 29201,
#  'dure restor': 12139,
#  'restor multipl': 31678,
#  'multipl user': 24333,
#  'user profiles': 39069,
#  'profiles user': 29484,
#  'restor privileg': 31682,
#  'privileg exploit': 28999,
#  'vulner obtain': 40478,
#  'obtain elev': 25235,
#  'privileg restor': 29050,
#  'restor ibm': 31677,
#  'ibm forc': 17563,
#  'lobbi track': 21919,
#  'track desktop': 37178,
#  'desktop contain': 10574,
#  'contain default': 8119,
#  'default administr': 10130,
#  'administr credentials': 1126,
#  'credentials attack': 9311,
#  'vulner gain': 40324,
#  'gain access': 16062,
#  'access application': 243,
#  'improp authent': 18233,
#  'authent issu': 3589,
#  'discov johnson': 11368,
#  'johnson johnson': 20353,
#  'johnson ethicon': 20352,
#  'ethicon endo': 13271,
#  'endo surgeri': 12842,
#  'surgeri generat': 36244,
#  'generat gen11': 16201,
#  'gen11 releas': 16180,
#  'releas befor': 30884,
#  'befor novemb': 4382,
#  'novemb secur': 25019,
#  'secur authent': 32976,
#  'authent mechan': 3599,
#  'mechan use': 23139,
#  'use ethicon': 38519,
#  'gen11 single': 16181,
#  'single pati': 34516,
#  'pati use': 27120,
#  'use product': 38677,
#  'product bypassed': 29353,
#  'bypassed allow': 5301,
#  'allow unauthor': 1882,
#  'unauthor devic': 37794,
#  'devic connect': 10699,
#  'connect generator': 7907,
#  'generator result': 16225,
#  'result loss': 31814,
#  'loss integr': 22299,
#  'integr availability': 19282,
#  'ibm webspher': 17596,
#  'webspher applic': 41084,
#  'applic server': 2602,
#  'server instal': 33499,
#  'instal use': 19137,
#  'use form': 38538,
#  'form login': 15470,
#  'login allow': 22139,
#  'attack conduct': 3145,
#  'conduct spoof': 7629,
#  'spoof attacks': 35260,
#  'attacks ibm': 3412,
#  'sugarcrm befor': 36119,
#  'befor befor': 4253,
#  'allow php': 1824,
#  'php code': 27561,
#  'code inject': 6872,
#  'inject mergerecord': 18816,
#  'mergerecord modul': 23350,
#  'modul develop': 24036,
#  'develop user': 10666,
#  'rcs modul': 30298,
#  'modul huawei': 24050,
#  'huawei alp': 17472,
#  'alp smart': 1910,
#  'smart phone': 34717,
#  'phone softwar': 27507,
#  'softwar earlier': 34889,
#  'earlier bla': 12207,
#  'bla smart': 4714,
#  'earlier remot': 12274,
#  'remot control': 31008,
#  'control vulnerability': 8536,
#  'vulnerability attack': 40721,
#  'attack trick': 3361,
#  'trick user': 37405,
#  'user instal': 38968,
#  'instal malici': 19106,
#  'malici application': 22555,
#  'application applic': 2621,
#  'applic connect': 2523,
#  'connect rcs': 7932,
#  'rcs time': 30299,
#  'time need': 36929,
#  'need user': 24512,
#  'user manual': 39012,
#  'manual click': 22902,
#  'click agree': 6510,
#  'agree addition': 1519,
#  'addition attack': 895,
#  'attack need': 3274,
#  'need obtain': 24501,
#  'obtain key': 25243,
#  'key rcs': 20632,
#  'rcs use': 30300,
#  'use authent': 38429,
#  'authent application': 3541,
#  'application success': 2645,
#  'exploit caus': 13927,
#  'caus attack': 5560,
#  'control keyboard': 8460,
#  'keyboard remotely': 20655,
#  'sql inject': 35315,
#  'inject vulner': 18865,
#  'vulner manag': 40436,
#  'manag interfac': 22746,
#  'interfac eport': 19460,
#  'eport manag': 13106,
#  'arbitrari sql': 2742,
#  'sql command': 35310,
#  'command unspecifi': 7195,
#  'unspecifi parameters': 38083,
#  'discov keybas': 11372,
#  'keybas command': 20648,
#  'command lin': 7147,
#  'lin client': 21644,
#  'client befor': 6541,
#  'befor linux': 4353,
#  'linux untrust': 21767,
#  'untrust search': 38110,
#  'search path': 32916,
#  'path vulner': 27111,
#  'vulner keybase': 40410,
#  'keybase redirector': 20649,
#  'redirector applic': 30690,
#  'applic allow': 2508,
#  'allow local': 1800,
#  'local unprivileg': 21968,
#  'unprivileg user': 38026,
#  'user linux': 38992,
#  'linux gain': 21750,
#  'gain root': 16083,
#  'root privileg': 32109,
#  'privileg trojan': 29064,
#  'trojan hors': 37483,
#  'hors binary': 17180,
#  'oracl outsid': 25876,
#  'outsid technolog': 26069,
#  'technolog compon': 36598,
#  'oracl fusion': 25862,
#  'fusion middlewar': 16046,
#  'middlewar subcomponent': 23622,
#  'subcomponent outsid': 35935,
#  'outsid filters': 26059,
#  'filters support': 15015,
#  'outsid technology': 26070,
#  'technology success': 36609,
#  'attack requir': 3323,
#  'requir human': 31424,
#  'human interact': 17498,
#  'interact person': 19399,
#  'person attacker': 27444,
#  'attacker success': 3400,
#  'technolog access': 36594,
#  'data unauthor': 9901,
#  'unauthor abil': 37785,
#  'abil caus': 110,
#  'caus partial': 5639,
#  'partial denial': 26822,
#  'denial servic': 10390,
#  'servic partial': 33782,
#  'partial dos': 26823,
#  'dos oracl': 11904,
#  'technology note': 36608,
#  'note outsid': 24985,
#  'technolog suit': 36604,
#  'suit softwar': 36139,
#  'softwar develop': 34884,
#  'develop kit': 10654,
#  'kit sdks': 20729,
#  'sdks protocol': 32869,
#  'protocol cvss': 29742,
#  'cvss score': 9631,
#  'score depend': 32724,
#  'depend softwar': 10411,
#  'softwar use': 34943,
#  'use outsid': 38647,
#  'technolog code': 36597,
#  'code cvss': 6837,
#  'score assum': 32718,
#  'assum softwar': 3032,
#  'softwar pass': 34914,
#  'pass data': 26855,
#  'data receiv': 9869,
#  'receiv network': 30562,
#  'network direct': 24621,
#  'direct outsid': 11055,
#  'code data': 6838,
#  'network cvss': 24617,
#  'score lower': 32726,
#  'lower cvss': 22311,
#  'confidenti avail': 7639,
#  'avail impacts': 3810,
#  'winlogbeat befor': 41304,
#  'befor insuffici': 4334,
#  'insuffici log': 19255,
#  'log attack': 22045,
#  'attack abl': 3093,
#  'abl inject': 153,
#  'inject certain': 18782,
#  'certain charact': 5783,
#  'charact log': 6060,
#  'log entri': 22060,
#  'entri prevent': 13047,
#  'prevent winlogbeat': 28690,
#  'winlogbeat record': 41305,
#  'record event': 30590,
#  'undisclos vulner': 37866,
#  'vulner ibm': 40356,
#  'ibm ration': 17581,
#  'ration door': 30274,
#  'door applic': 11880,
#  'attack gain': 3212,
#  'gain door': 16071,
#  'door administr': 11879,
#  'administr privileges': 1156,
#  'privileges ibm': 29094,
#  'eclips vert': 12350,
#  'vert csrfhandler': 39833,
#  'csrfhandler assert': 9511,
#  'assert xsrf': 2979,
#  'xsrf cooki': 41739,
#  'cooki match': 8611,
#  'match return': 22988,
#  'return xsrf': 31920,
#  'xsrf header': 41740,
#  'header form': 16950,
#  'form parameter': 15473,
#  'parameter allow': 26660,
#  'allow replay': 1844,
#  'replay attack': 31138,
#  'attack previous': 3302,
#  'previous issu': 28705,
#  'issu token': 19948,
#  'token expir': 37059,
#  'dell emc': 10302,
#  'emc uniti': 12650,
#  'uniti unityvsa': 37978,
#  'unityvsa prior': 37981,
#  'prior contain': 28799,
#  'contain url': 8199,
#  'url redirect': 38355,
#  'redirect vulnerability': 30686,
#  'vulnerability remot': 40748,
#  'remot unauthent': 31049,
#  'attack potenti': 3299,
#  'potenti exploit': 28514,
#  'vulner redirect': 40552,
#  'redirect uniti': 30680,
#  'uniti user': 37979,
#  'user arbitrari': 38849,
#  'web url': 40975,
#  'url trick': 38364,
#  'trick victim': 37406,
#  'victim user': 39882,
#  'user click': 38874,
#  'click malici': 6516,
#  'malici craft': 22570,
#  'craft unispher': 9037,
#  'unispher url': 37960,
#  'url attack': 38307,
#  'potenti phish': 28535,
#  'phish information': 27486,
#  'information includ': 18683,
#  'includ unispher': 18372,
#  'unispher user': 37961,
#  'user credentials': 38898,
#  'credentials victim': 9319,
#  'victim onc': 39873,
#  'onc redirected': 25457,
#  'razorcm allow': 30285,
#  'allow html': 1788,
#  'html inject': 17337,
#  'inject descript': 18790,
#  'descript homepag': 10502,
#  'homepag set': 17160,
#  'set component': 34020,
#  'discov prtg': 11444,
#  'prtg network': 29907,
#  'network monitor': 24653,
#  'monitor befor': 24133,
#  'befor attack': 4247,
#  'access prtg': 438,
#  'prtg administr': 29906,
#  'administr web': 1180,
#  'web consol': 40919,
#  'consol administr': 8000,
#  'administr privileg': 1155,
#  'exploit command': 13929,
#  'command inject': 7135,
#  'vulner server': 40584,
#  'server devices': 33459,
#  'devices send': 10893,
#  'send malform': 33170,
#  'malform paramet': 22532,
#  'paramet sensor': 26628,
#  'sensor notif': 33236,
#  'notif manag': 25008,
#  'manag scenarios': 22793,
#  'xss exist': 41779,
#  'exist dilicm': 13695,
#  'dilicm admin': 11014,
#  'admin index': 1037,
#  'index php': 18510,
#  'php setting': 27698,
#  'setting site': 34107,
#  'site tab': 34578,
#  'tab site_attach': 36404,
#  'site_attach attachment_typ': 34588,
#  'attachment_typ parameter': 3090,
#  'tribul slideshow': 37394,
#  'slideshow galleri': 34683,
#  'galleri plugin': 16097,
#  'plugin befor': 28022,
#  'befor wordpress': 4474,
#  'wordpress xss': 41413,
#  'xss method': 41808,
#  'method gallerymessage': 23503,
#  'gallerymessage galleryerror': 16101,
#  'galleryerror galleryupd': 16100,
#  'galleryupd parameter': 16102,
#  'cisco webex': 6381,
#  'webex network': 41008,
#  'network record': 24669,
#  'record player': 30597,
#  'player microsoft': 27991,
#  'microsoft window': 23609,
#  'window cisco': 41209,
#  'webex player': 41009,
#  'window allow': 41204,
#  'code affect': 6803,
#  'valid advanc': 39314,
#  'advanc record': 1229,
#  'record format': 30591,
#  'format arf': 15489,
#  'arf webex': 2807,
#  'webex record': 41010,
#  'format wrf': 15505,
#  'wrf files': 41502,
#  'files attack': 14924,
#  'send user': 33199,
#  'user malici': 39008,
#  'malici arf': 22556,
#  'arf wrf': 2808,
#  'wrf file': 41501,
#  'file link': 14723,
#  'link email': 21693,
#  'email attach': 12578,
#  'attach persuad': 3080,
#  'persuad user': 27452,
#  'user open': 39033,
#  'open file': 25597,
#  'file use': 14868,
#  'use affect': 38409,
#  'affect software': 1429,
#  'software success': 34963,
#  'reflect cross': 30733,
#  'cross site': 9354,
#  'site script': 34574,
#  'script vulner': 32828,
#  'vulner administr': 40178,
#  'consol mcafe': 8011,
#  'mcafe web': 23056,
#  'web gateway': 40929,
#  'gateway mwg': 16134,
#  'mwg prior': 24364,
#  'attack collect': 3138,
#  'collect sensit': 7020,
#  'inform execut': 18587,
#  'execut command': 13460,
#  'command mwg': 7160,
#  'mwg administr': 24360,
#  'administr credenti': 1125,
#  'credenti trick': 9296,
#  'trick administr': 37398,
#  'administr click': 1120,
#  'click care': 6513,
#  'care construct': 5487,
#  'construct malici': 8049,
#  'malici link': 22599,
#  'accesslogfilt class': 516,
#  'class jira': 6423,
#  'jira befor': 20314,
#  'remot anonym': 30989,
#  'anonym attack': 2152,
#  'attack learn': 3251,
#  'learn users': 21228,
#  'users includ': 39225,
#  'includ username': 18375,
#  'username inform': 39197,
#  'inform expos': 18589,
#  'expos cach': 14076,
#  'cach vulner': 5350,
#  'vulner jira': 40406,
#  'jira configur': 20316,
#  'configur revers': 7775,
#  'revers proxi': 31953,
#  'proxi load': 29885,
#  'load balanc': 21861,
#  'balanc cach': 3950,
#  'cach cdn': 5333,
#  'exist handl': 13718,
#  'handl templat': 16771,
#  'templat objects': 36657,
#  'objects issu': 25207,
#  'privileg vulner': 29073,
#  'exist window': 13844,
#  'window window': 41283,
#  'window kernel': 41237,
#  'kernel mod': 20560,
#  'mod driver': 23837,
#  'driver fail': 12009,
#  'fail proper': 14337,
#  'proper handl': 29607,
#  'aka win32k': 1640,
#  'win32k elev': 41184,
#  'privileg vulnerability': 29074,
#  'vulnerability cve': 40727,
#  'cve uniqu': 9621,
#  'uniqu cve': 37956,
#  'ibm secur': 17585,
#  'secur key': 33008,
#  'key lifecycl': 20621,
#  'lifecycl manag': 21588,
#  'unauthent user': 37776,
#  'user restart': 39087,
#  'restart sklm': 31667,
#  'sklm server': 34650,
#  'server miss': 33522,
#  'miss authentication': 23735,
#  'authentication ibm': 3677,
#  'drivers scsi': 12045,
#  'scsi qla2xxx': 32847,
#  'qla2xxx qla_os': 30103,
#  'qla_os linux': 30104,
#  'linux kernel': 21754,
#  'kernel doe': 20540,
#  'doe check': 11771,
#  'check alloc_workqueu': 6092,
#  'alloc_workqueu return': 1718,
#  'return value': 31919,
#  'value lead': 39552,
#  'lead null': 21113,
#  'null pointer': 25062,
#  'pointer dereference': 28139,
#  'adob acrobat': 1198,
#  'acrobat reader': 659,
#  'reader earlier': 30472,
#  'earlier earlier': 12229,
#  'earlier bound': 12210,
#  'bound write': 4888,
#  'write vulnerability': 41576,
#  'vulnerability success': 40753,
#  'exploit lead': 13961,
#  'lead arbitrari': 21054,
#  'code execution': 6855,
#  'unifi contact': 37919,
#  'contact center': 8092,
#  'center express': 5741,
#  'express uccx': 14149,
#  'uccx softwar': 37686,
#  'softwar allow': 34868,
#  'allow unauthenticated': 1881,
#  'unauthenticated remot': 37782,
#  'conduct http': 7621,
#  'http respons': 17426,
#  'respons split': 31613,
#  'split attack': 35251,
#  'vulner insuffici': 40385,
#  'insuffici input': 19253,
#  'paramet pass': 26608,
#  'pass web': 26882,
#  'web server': 40959,
#  'server affect': 33400,
#  'affect attack': 1285,
#  'vulner convinc': 40252,
#  'convinc user': 8592,
#  'user follow': 38943,
#  'follow malici': 15366,
#  'link intercept': 21700,
#  'intercept user': 19428,
#  'user request': 39084,
#  'affect device': 1310,
#  'device success': 10854,
#  'perform cross': 27278,
#  'script attacks': 32758,
#  'attacks web': 3425,
#  'cach poisoning': 5347,
#  'poisoning access': 28170,
#  'sensit browser': 33218,
#  'browser bas': 4989,
#  'bas information': 3992,
#  'information similar': 18689,
#  'similar exploits': 34448,
#  'improp input': 18252,
#  'valid dnssec': 39356,
#  'dnssec valid': 11693,
#  'valid compon': 39338,
#  'compon powerdn': 7423,
#  'powerdn allow': 28563,
#  'attack man': 3264,
#  'man middl': 22680,
#  'middl posit': 23618,
#  'posit deni': 28358,
#  'deni exist': 10387,
#  'exist data': 13690,
#  'data dns': 9772,
#  'dns packet': 11679,
#  'packet replay': 26338,
#  'discov xen': 11520,
#  'xen amd': 41652,
#  'amd platforms': 1953,
#  'platforms possibl': 27970,
#  'possibl allow': 28373,
#  'allow guest': 1783,
#  'guest user': 16623,
#  'user gain': 38947,
#  'gain host': 16073,
#  'host privileg': 17226,
#  'privileg becaus': 28971,
#  'becaus tlb': 4190,
#  'tlb flush': 36989,
#  'flush alway': 15305,
#  'alway occur': 1939,
#  'occur iommu': 25308,
#  'iommu map': 19738,
#  'map changes': 22918,
#  'implement ico': 18132,
#  'ico dollar': 17628,
#  'dollar icod': 11838,
#  'icod ethereum': 17631,
#  ...}

# %%
## How much the method produces false positives if a security specialist needs to proritize them

# %%
vulns_common.print_classified_dataset('data/Ambari.csv', c)
vulns_common.print_classified_dataset('data/Camel.csv', c)
vulns_common.print_classified_dataset('data/Wicket.csv', c)
vulns_common.print_classified_dataset('data/Chromium.csv', c)
vulns_common.print_classified_dataset('data/Derby.csv', c)
# Out:
# Test on data/Ambari.csv. Rows: 1000
#               precision    recall  f1-score   support
#
#        False       0.98      0.82      0.89       971
#         True       0.07      0.45      0.12        29
#
#    micro avg       0.81      0.81      0.81      1000
#    macro avg       0.52      0.63      0.50      1000
# weighted avg       0.95      0.81      0.87      1000
#
# TN=793, FP=178, FN=16, TP=13
# Test on data/Camel.csv. Rows: 1000
#               precision    recall  f1-score   support
#
#        False       0.97      0.77      0.86       967
#         True       0.05      0.34      0.08        32
#
#    micro avg       0.75      0.75      0.75       999
#    macro avg       0.51      0.56      0.47       999
# weighted avg       0.94      0.75      0.83       999
#
# TN=743, FP=224, FN=21, TP=11
# Test on data/Wicket.csv. Rows: 1000
#               precision    recall  f1-score   support
#
#        False       0.99      0.81      0.89       990
#         True       0.03      0.50      0.05        10
#
#    micro avg       0.81      0.81      0.81      1000
#    macro avg       0.51      0.65      0.47      1000
# weighted avg       0.98      0.81      0.88      1000
#
# TN=800, FP=190, FN=5, TP=5
# Test on data/Chromium.csv. Rows: 1000
#               precision    recall  f1-score   support
#
#        False       1.00      0.77      0.87       995
#         True       0.01      0.60      0.03         5
#
#    micro avg       0.77      0.77      0.77      1000
#    macro avg       0.51      0.69      0.45      1000
# weighted avg       0.99      0.77      0.87      1000
#
# TN=769, FP=226, FN=2, TP=3
# Test on data/Derby.csv. Rows: 1000
#               precision    recall  f1-score   support
#
#        False       0.94      0.71      0.81       910
#         True       0.15      0.51      0.23        88
#
#    micro avg       0.69      0.69      0.69       998
#    macro avg       0.54      0.61      0.52       998
# weighted avg       0.87      0.69      0.76       998
#
# TN=647, FP=263, FN=43, TP=45

# %%
## Find optimal dataset size to fit the classifier

# %%
sample_sizes = [100, 500, 1000, 2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000]

final_results = []
for size in sample_sizes:
    results = 0

    for n in range(10):#cross validation
        vuln_data = shuffle(nvd_vulns, n_samples=size)
        vuln_descs = []
        for d in vuln_data:
            vuln_descs.append(d[1])
        mixed = vulns_common.get_mixed_dataset(reports['report'], 1000)
    
        c.fit(vuln_descs)
        predicted = c.predict(mixed['report'])
        #score = f1_score(y_true=mixed['security'], y_pred=predicted, average='micro)
        score = roc_auc_score(y_true=mixed['security'], y_score=predicted, average='micro')
        results= results + score

    final_results.append([str(size), results/10])
    print(str(results/10))

print('done')
# Out:
# 0.6180364864864865
# 0.6898175675675675
# 0.7238081081081083
# 0.7338702702702703
# 0.7327972972972974
# 0.7317837837837838
# 0.7305135135135136
# 0.7193581081081081
# 0.7183324324324325
# 0.7030702702702704
# 0.7080554054054053
# 0.6971216216216217
# done
