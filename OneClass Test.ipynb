# %% [markdown]
# ## Find vulnerabilities using OneClass Classifiers

# %%
from sklearn.utils import shuffle
import vulns_common

vulns_common.download_nvd_vulns_json()
nvd_vulns = vulns_common.load_nvd_vulns_json('data/nvdcve-1.0*.json')
print('Vulnerability descriptions: ' + str(len(nvd_vulns)))
cpe_names = vulns_common.compile_cpe_names(nvd_vulns)
print('Vulnerable product names:'+str(len(cpe_names)))
vuln_data = shuffle(nvd_vulns, n_samples=6000)
print('Vulnerability learning data: ' + str(len(vuln_data)))
# Out:
# Vulnerability descriptions: 32963
# Vulnerable product names:9176
# Vulnerability learning data: 6000

# %%
vuln_data[0]
# Out:
# ['CVE-2018-1000401',
#  'Jenkins project Jenkins AWS CodePipeline Plugin version 0.36 and earlier contains a Insufficiently Protected Credentials vulnerability in AWSCodePipelineSCM.java that can result in Credentials Disclosure. This attack appear to be exploitable via local file access. This vulnerability appears to have been fixed in 0.37 and later.',
#  'CWE-522',
#  'AV:L/AC:L/Au:N/C:P/I:N/A:N',
#  2.1,
#  'CVSS:3.0/AV:L/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H',
#  7.8,
#  ['jenkins', 'aws_codepipeline']]

# %%
import pandas as pd
vuln_descs = []
for d in vuln_data:
    if not d[1].startswith('** REJECT'):#a few descriptions are rejected by NVD
        vuln_descs.append(d[1])

reports = pd.read_excel('data/sec_issues_edit.xlsx')
reports = reports.loc[(reports['security']==1)]
reports['security'] = reports['security'].values.astype(bool)
reports['report'] = reports['report'].values.astype(str)
print('Manually labeled vulnerability dataset: '+ str(len(reports)))
print('Mixed with non-security issues')
mixed = vulns_common.get_mixed_dataset(reports['report'], 1000)
print(mixed.shape)
mixed.head(10)
# Out:
# Manually labeled vulnerability dataset: 148
# Mixed with non-security issues
# (1148, 2)
#                                                   report  security
# 807    Mail component does not work as expected (Emai...        -1
# 261    Password field submitted using GET method This...         1
# 775    Issue 783 : Customisation of new tab page 3   ...        -1
# 76     [PATCH] remove XX in firefox and palette   I k...        -1
# 276    LangScripts JUnit test fails in views.sql   La...        -1
# 540    tools/ide is not included in the source tarbal...        -1
# 703    ClassCastException when calling boolean meta-d...        -1
# 364    Incorrect privileges may be required for INSER...         1
# 23341  Issue 24594 : Crash - v8::internal::MarkingVis...        -1
# 860    Component.continueToOriginalDestination() can ...        -1

# %% [markdown]
# ## Sklearn Vectorizers

# %%
from sklearn.feature_extraction.text import CountVectorizer #Term Frequencies
from sklearn.feature_extraction.text import TfidfVectorizer #Term Frequency times inverse document frequency
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from nltk.stem.snowball import SnowballStemmer
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction import text 
import numpy as np
import time

class StemmedCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        self.stemmer = SnowballStemmer("english")
        analyzer = super(CountVectorizer, self).build_analyzer()
        return lambda doc: (analyzer(' '.join([self.stemmer.stem(word) for word in doc.split(' ')])))

class StemmedTfidfVectorizer(TfidfVectorizer):
    def build_analyzer(self):
        self.stemmer = SnowballStemmer("english")
        analyzer = super(TfidfVectorizer, self).build_analyzer()
        return lambda doc: (analyzer(' '.join([self.stemmer.stem(word) for word in doc.split(' ')])))

class LemmaCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        self.stemmer = WordNetLemmatizer()
        analyzer = super(CountVectorizer, self).build_analyzer()
        return lambda doc: (analyzer(' '.join([self.stemmer.lemmatize(word) for word in doc.split(' ')])))    

class LemmaTfidfVectorizer(TfidfVectorizer):
    def build_analyzer(self):
        self.stemmer = WordNetLemmatizer()
        analyzer = super(TfidfVectorizer, self).build_analyzer()
        return lambda doc: (analyzer(' '.join([self.stemmer.lemmatize(word) for word in doc.split(' ')])))   
    
nfold = 10

def run_test(vzr, cls):
    print(str(cls)[0:str(cls).find('(')] + ' ' + str(vzr)[0:str(vzr).find('(')])

    #get a new testing set
    mixed = vulns_common.get_mixed_dataset(reports['report'], 1000)    
    
    scores = []
    t = time.time()
    for i in range(nfold): #n-fold cross val score
        predicted = pipe.predict(mixed['report'])
        #score = f1_score(y_true=mixed['security'], y_pred=predicted, average='micro')
        score = roc_auc_score(y_true=mixed['security'], y_score=predicted, average='micro')
        scores.append(score)
    
    scores = np.array(scores)
    print(str(nfold)+'-fold cross validated roc-auc-score:' + str(scores.mean()) + '\n')
    print('Time taken: ' + str(round(time.time() - t, 1)) + 's')

classifiers = [
    OneClassSVM(gamma='scale', kernel='linear', nu=0.2, shrinking=True, tol=1e-05),
    #OneClassSVM(gamma='scale'),
    #IsolationForest(contamination='auto', behaviour='new'),
    #LocalOutlierFactor(novelty=True, contamination='auto')
]

print('Mixed dataset for predict: '+ str(len(mixed)))

df = 1
l = True
t = r'\b\w*[a-zA-Z]{3,}\w*\b'#default: r'\b\w+\b'
ngram_s = 1
ngram_e = 2

unwanted_words = ['issue','defect','bug','fault','flaw','mistake','error','version','system','because','before','disputed']
stop_words = text.ENGLISH_STOP_WORDS#.union(cpe_names)
stop_words = stop_words.union(unwanted_words)

vectorizers = [
               #CountVectorizer(stop_words=stop_words, lowercase=l, ngram_range=(ngram_s, ngram_e), min_df=df, token_pattern=t),
               #StemmedCountVectorizer(stop_words=stop_words, lowercase=l, ngram_range=(ngram_s, ngram_e), min_df=df, token_pattern=t),
               #TfidfVectorizer(stop_words=stop_words, lowercase=l, ngram_range=(ngram_s, ngram_e), min_df=df, token_pattern=t),
               #StemmedTfidfVectorizer(stop_words=stop_words, lowercase=l, ngram_range=(ngram_s, ngram_e), min_df=df, token_pattern=t),
               LemmaTfidfVectorizer(stop_words=stop_words, lowercase=l, ngram_range=(ngram_s, ngram_e), min_df=df, token_pattern=t),
               #LemmaCountVectorizer(stop_words=stop_words, lowercase=l, ngram_range=(ngram_s, ngram_e), min_df=df, token_pattern=t),
              ]

for c in classifiers:
    for v in vectorizers:
        pipe = Pipeline([('vect', v), ('clf', c)])
        #get a new learning data before the fit method
        vuln_data = shuffle(nvd_vulns, n_samples=6000)
        vuln_descs = []
        for d in vuln_data:
            if not d[1].startswith('** REJECT'):#some descriptions are rejected by NVD
                vuln_descs.append(d[1])
        print('Dataset to fit:'+str(len(vuln_descs)))
        pipe = pipe.fit(vuln_descs)
        run_test(v, c)
# Out:
# Mixed dataset for predict: 1148
# Dataset to fit:5823
# OneClassSVM LemmaTfidfVectorizer
# 10-fold cross validated roc-auc-score:0.7296216216216216
#
# Time taken: 16.8s

# %%
vectorizer = LemmaTfidfVectorizer(stop_words=stop_words, lowercase=l, ngram_range=(ngram_s, ngram_e), min_df=df, token_pattern=t)

vectors = vectorizer.fit_transform(vuln_descs)
print("Vectors shape:" + str(vectors.shape))
# Out:
# Vectors shape:(5823, 69609)

# %%
p = shuffle(vuln_descs, n_samples=1)
print(p[0])
vectors = vectorizer.transform(p)
print(c.score_samples(vectors)-c.offset_)
print(c.predict(vectors))

p = reports.sample(n=1)
print(p['report'].iloc[0])
vectors = vectorizer.transform(p['report'])
print(c.score_samples(vectors)-c.offset_)
print(c.predict(vectors))

p = mixed.sample(n=1)
print(p['report'].iloc[0])
print(p['security'].iloc[0])
vectors = vectorizer.transform(p['report'])
print(c.score_samples(vectors)-c.offset_)
print(c.predict(vectors))
# Out:
# A vulnerability in unit_deserialize of systemd allows an attacker to supply arbitrary state across systemd re-execution via NotifyAccess. This can be used to improperly influence systemd execution and possibly lead to root privilege escalation. Affected releases are systemd versions up to and including 239.
# [2.86537603e-06]
# [1]
# Add Support for network Server USRIDONL security   Currently Network Server supports only two security mechanisms.User ID and password (usridpwd)User ID and encrypted password (eusridpwd)It would be good to add support for User ID Only security so that it could more closely match the embedded driver and not always require a password.See details of security mechanism implementations in section 4.4.2.1 of DRDA V3 Vol. 1: Distributed Relational Database Architecture http://www.opengroup.org/dbiop/
# [3.1373414]
# [1]
# BlueprintCamelContext should not get started in the init() method but later when the blueprint container is fully initialized   The init() method in BlueprintCamelContext should not call maybeStart(). but instead should be started when the blueprint container is done doing all its dance and initialization.For example Spring sends on ContextRefreshedEvent when its done.We need something similar for blueprint to tell us when its done doing its initialization et all.The problem is that the CamelContext should not be started until all that other stuff is initialized as well.
# -1
# [-2.50466645]
# [-1]

# %%
## how it finds manually labeled vulnerability issues

# %%
pipe = Pipeline([('vect', vectorizer), ('clf', c)])
pipe = pipe.fit(vuln_descs)

# %%
vectorizer.vocabulary_
# Out:
# {'vulnerability': 66403,
#  'identified': 28839,
#  'simatic': 56671,
#  'open': 42054,
#  'controller': 13406,
#  'cpu': 14039,
#  'versions': 65683,
#  'family': 23191,
#  'software': 57413,
#  'plcsim': 46070,
#  'advanced': 2062,
#  'attacker': 5127,
#  'man': 37078,
#  'middle': 38602,
#  'position': 46636,
#  'potentially': 46890,
#  'modify': 39242,
#  'network': 40443,
#  'traffic': 61567,
#  'exchanged': 21609,
#  'port': 46468,
#  'tcp': 60333,
#  'certain': 9134,
#  'property': 48615,
#  'calculation': 8263,
#  'used': 63808,
#  'integrity': 31527,
#  'protection': 48693,
#  'order': 42637,
#  'exploit': 22441,
#  'able': 338,
#  'perform': 44883,
#  'attack': 4971,
#  'impact': 29383,
#  'communication': 11471,
#  'public': 49073,
#  'exploitation': 22562,
#  'known': 33816,
#  'time': 61063,
#  'advisory': 2110,
#  'publication': 49097,
#  'vulnerability identified': 66663,
#  'identified simatic': 28867,
#  'simatic open': 56680,
#  'open controller': 42073,
#  'controller cpu': 13424,
#  'cpu versions': 14059,
#  'versions simatic': 65745,
#  'simatic cpu': 56676,
#  'cpu family': 14046,
#  'family simatic': 23198,
#  'family versions': 23199,
#  'simatic software': 56684,
#  'software controller': 57436,
#  'controller versions': 13462,
#  'simatic plcsim': 56682,
#  'plcsim advanced': 46071,
#  'advanced versions': 2079,
#  'versions attacker': 65690,
#  'attacker man': 5311,
#  'man middle': 37081,
#  'middle position': 38612,
#  'position potentially': 46645,
#  'potentially modify': 46937,
#  'modify network': 39272,
#  'network traffic': 40554,
#  'traffic exchanged': 61581,
#  'exchanged port': 21610,
#  'port tcp': 46520,
#  'tcp certain': 60340,
#  'certain property': 9213,
#  'property calculation': 48621,
#  'calculation used': 8269,
#  'used integrity': 63915,
#  'integrity protection': 31546,
#  'protection order': 48729,
#  'order exploit': 42644,
#  'exploit vulnerability': 22488,
#  'vulnerability attacker': 66449,
#  'attacker able': 5129,
#  'able perform': 381,
#  'perform man': 44918,
#  'middle attack': 38605,
#  'attack vulnerability': 5119,
#  'vulnerability impact': 66668,
#  'impact integrity': 29412,
#  'integrity communication': 31534,
#  'communication public': 11496,
#  'public exploitation': 49078,
#  'exploitation vulnerability': 22586,
#  'vulnerability known': 66723,
#  'known time': 33838,
#  'time advisory': 61065,
#  'advisory publication': 2114,
#  'incorrect': 30077,
#  'default': 16387,
#  'permissions': 45112,
#  'discovered': 18157,
#  'azeotech': 6252,
#  'daqfactory': 15720,
#  'prior': 47356,
#  'local': 35778,
#  'non': 40935,
#  'administrative': 1869,
#  'user': 64019,
#  'replace': 51292,
#  'original': 42725,
#  'application': 3967,
#  'file': 23546,
#  'malicious': 36892,
#  'ones': 41975,
#  'incorrect default': 30088,
#  'default permissions': 16441,
#  'permissions discovered': 45121,
#  'discovered azeotech': 18178,
#  'azeotech daqfactory': 6253,
#  'daqfactory prior': 15721,
#  'prior local': 47466,
#  'local non': 35821,
#  'non administrative': 40937,
#  'administrative user': 1897,
#  'user able': 64021,
#  'able replace': 386,
#  'replace modify': 51299,
#  'modify original': 39274,
#  'original application': 42726,
#  'application file': 4042,
#  'file malicious': 23784,
#  'malicious ones': 36969,
#  'web': 67459,
#  'console': 12603,
#  'javascript': 32769,
#  'debugger': 16257,
#  'sanitize': 53655,
#  'output': 42841,
#  'hyperlinked': 28632,
#  'display': 18539,
#  'chrome': 9836,
#  'link': 35343,
#  'active': 1258,
#  'clickable': 10251,
#  'hyperlink': 28626,
#  'site': 56849,
#  'directly': 17838,
#  'internal': 31874,
#  'pages': 43602,
#  'additionally': 1503,
#  'links': 35433,
#  'tricked': 61869,
#  'clicking': 10261,
#  'sites': 56928,
#  'affect': 2156,
#  'firefox': 24319,
#  'web console': 67482,
#  'console javascript': 12625,
#  'javascript debugger': 32783,
#  'debugger sanitize': 16260,
#  'sanitize output': 53664,
#  'output hyperlinked': 42857,
#  'hyperlinked display': 28633,
#  'display chrome': 18542,
#  'chrome link': 9840,
#  'link active': 35345,
#  'active clickable': 1260,
#  'clickable hyperlink': 10254,
#  'hyperlink output': 28628,
#  'output web': 42872,
#  'web site': 67529,
#  'site able': 56850,
#  'able directly': 356,
#  'directly link': 17854,
#  'link internal': 35383,
#  'internal chrome': 31878,
#  'chrome pages': 9842,
#  'pages additionally': 43606,
#  'additionally javascript': 1508,
#  'debugger display': 16258,
#  'display javascript': 18554,
#  'javascript links': 32803,
#  'links user': 35440,
#  'user tricked': 64421,
#  'tricked clicking': 61872,
#  'clicking malicious': 10265,
#  'malicious sites': 36999,
#  'sites vulnerability': 56932,
#  'vulnerability affect': 66424,
#  'affect firefox': 2177,
#  'cross': 14816,
#  'scripting': 54164,
#  'edirectory': 19894,
#  'cross site': 14828,
#  'site scripting': 56889,
#  'scripting vulnerability': 54194,
#  'vulnerability edirectory': 66568,
#  'edirectory prior': 19896,
#  'siemens': 56536,
#  'keypad': 33668,
#  'designer': 17069,
#  'dll': 18689,
#  'hijacking': 27891,
#  'exists': 22108,
#  'allow': 2897,
#  'execute': 21694,
#  'code': 10703,
#  'permission': 45009,
#  'running': 53295,
#  'write': 68536,
#  'access': 496,
#  'directory': 17889,
#  'containing': 12873,
#  'project': 48458,
#  'legitimate': 34596,
#  'higher': 27858,
#  'privilege': 47640,
#  'exploited': 22587,
#  'security': 54527,
#  'identified siemens': 28866,
#  'siemens keypad': 56540,
#  'keypad designer': 33669,
#  'designer versions': 17074,
#  'versions dll': 65705,
#  'dll hijacking': 18707,
#  'hijacking vulnerability': 27898,
#  'vulnerability exists': 66592,
#  'exists siemens': 22293,
#  'designer allow': 17070,
#  'allow attacker': 2905,
#  'attacker execute': 5237,
#  'execute code': 21703,
#  'code permission': 10856,
#  'permission user': 45099,
#  'user running': 64369,
#  'running designer': 53317,
#  'designer attacker': 17071,
#  'attacker write': 5448,
#  'write access': 68539,
#  'access directory': 594,
#  'directory containing': 17904,
#  'containing project': 12899,
#  'project file': 48467,
#  'file order': 23819,
#  'vulnerability legitimate': 66732,
#  'legitimate user': 34599,
#  'user higher': 64205,
#  'higher privilege': 27864,
#  'privilege attacker': 47658,
#  'attacker open': 5331,
#  'open project': 42106,
#  'project order': 48476,
#  'order vulnerability': 42657,
#  'vulnerability exploited': 66596,
#  'exploited time': 22623,
#  'publication public': 49099,
#  'exploitation security': 22582,
#  'security vulnerability': 54638,
#  'publiccms': 49100,
#  'csrf': 15283,
#  'admin': 1680,
#  'sysuser': 60051,
#  'save': 53777,
#  'callbacktype': 8287,
#  'closecurrent': 10466,
#  'navtabid': 40136,
#  'list': 35499,
#  'add': 1367,
#  'account': 909,
#  'discovered publiccms': 18380,
#  'publiccms csrf': 49101,
#  'csrf vulnerability': 15325,
#  'vulnerability admin': 66416,
#  'admin sysuser': 1800,
#  'sysuser save': 60053,
#  'save callbacktype': 53780,
#  'callbacktype closecurrent': 8288,
#  'closecurrent navtabid': 10467,
#  'navtabid sysuser': 40137,
#  'sysuser list': 60052,
#  'list add': 35501,
#  'add admin': 1368,
#  'admin account': 1683,
#  'schneider': 53964,
#  'electric': 20122,
#  'wiser': 68187,
#  'knx': 33842,
#  'homelynk': 28011,
#  'spacelynk': 57740,
#  'weak': 67409,
#  'unprotected': 62930,
#  'ftp': 25506,
#  'unauthorized': 62505,
#  'schneider electric': 53965,
#  'electric wiser': 20135,
#  'wiser knx': 68188,
#  'knx prior': 33843,
#  'prior homelynk': 47436,
#  'homelynk prior': 28012,
#  'prior spacelynk': 47544,
#  'spacelynk prior': 57741,
#  'prior weak': 47587,
#  'weak unprotected': 67427,
#  'unprotected ftp': 62934,
#  'ftp access': 25507,
#  'access allow': 513,
#  'attacker unauthorized': 5428,
#  'unauthorized access': 62507,
#  'qfx5000': 49357,
#  'series': 55058,
#  'switches': 59801,
#  'high': 27836,
#  'rate': 49691,
#  'ethernet': 21373,
#  'pause': 44589,
#  'frame': 25255,
#  'arp': 4566,
#  'packet': 43269,
#  'storm': 58882,
#  'received': 50243,
#  'management': 37123,
#  'interface': 31718,
#  'fxp0': 26009,
#  'cause': 8696,
#  'egress': 20082,
#  'congestion': 12361,
#  'resulting': 52363,
#  'routing': 53007,
#  'protocol': 48759,
#  'drops': 19431,
#  'bgp': 6751,
#  'leading': 34391,
#  'peering': 44837,
#  'flaps': 24604,
#  'following': 24832,
#  'log': 36004,
#  'message': 38216,
#  'displayed': 18576,
#  'fpc0': 25222,
#  'dcbcm_check_stuck_buffers': 16174,
#  'buffers': 7813,
#  'stuck': 59064,
#  'queue': 49514,
#  'product': 48203,
#  'qfx5100': 49359,
#  'qfx5110': 49363,
#  'qfx5200': 49367,
#  'qfx5210': 49374,
#  'switch': 59778,
#  'platform': 45942,
#  'affected': 2250,
#  'release': 50879,
#  'juniper': 33326,
#  'networks': 40577,
#  'junos': 33332,
#  'qfx5000 series': 49358,
#  'series switches': 55121,
#  'switches high': 59806,
#  'high rate': 27849,
#  'rate ethernet': 49693,
#  'ethernet pause': 21383,
#  'pause frame': 44590,
#  'frame arp': 25258,
#  'arp packet': 4567,
#  'packet storm': 43377,
#  'storm received': 58886,
#  'received management': 50257,
#  'management interface': 37178,
#  'interface fxp0': 31773,
#  'fxp0 cause': 26010,
#  'cause egress': 8743,
#  'egress interface': 20084,
#  'interface congestion': 31749,
#  'congestion resulting': 12362,
#  'resulting routing': 52410,
#  'routing protocol': 53015,
#  'protocol packet': 48806,
#  'packet drops': 43310,
#  'drops bgp': 19432,
#  'bgp leading': 6757,
#  'leading peering': 34432,
#  'peering flaps': 44838,
#  'flaps following': 24605,
#  'following log': 24846,
#  'log message': 36044,
#  'message displayed': 38243,
#  'displayed fpc0': 18583,
#  'fpc0 dcbcm_check_stuck_buffers': 25223,
#  'dcbcm_check_stuck_buffers buffers': 16175,
#  'buffers stuck': 7815,
#  'stuck queue': 59066,
#  'queue port': 49518,
#  'port affect': 46471,
#  'affect qfx5000': 2219,
#  'series product': 55105,
#  'product qfx5100': 48257,
#  'qfx5100 qfx5110': 49361,
#  'qfx5110 qfx5200': 49365,
#  'qfx5200 qfx5210': 49372,
#  'qfx5210 switch': 49375,
#  'switch platform': 59794,
#  'platform affected': 45946,
#  'affected affected': 2253,
#  'affected release': 2371,
#  'release juniper': 50904,
#  'juniper networks': 33330,
#  'networks junos': 40582,
#  'junos prior': 33348,
#  'prior qfx5000': 47518,
#  'series prior': 55104,
#  'header': 27618,
#  'injection': 30704,
#  'certec': 9249,
#  'edv': 20036,
#  'gmbh': 26653,
#  'atvise': 5581,
#  'scada': 53858,
#  'improper': 29763,
#  'neutralization': 40592,
#  'http': 28379,
#  'syntax': 59952,
#  'remote': 51049,
#  'execution': 21831,
#  'header injection': 27643,
#  'injection discovered': 30745,
#  'discovered certec': 18201,
#  'certec edv': 9250,
#  'edv gmbh': 20037,
#  'gmbh atvise': 26654,
#  'atvise scada': 5582,
#  'scada prior': 53866,
#  'prior improper': 47442,
#  'improper neutralization': 29794,
#  'neutralization http': 40593,
#  'http header': 28411,
#  'header scripting': 27660,
#  'scripting syntax': 54190,
#  'syntax identified': 59955,
#  'identified allow': 28842,
#  'allow remote': 2965,
#  'remote code': 51068,
#  'code execution': 10777,
#  'command': 11172,
#  'trend': 61851,
#  'micro': 38518,
#  'email': 20255,
#  'encryption': 20590,
#  'gateway': 26138,
#  'arbitrary': 4305,
#  'vulnerable': 67095,
#  'installation': 31185,
#  'launcherserver': 34202,
#  'authentication': 5728,
#  'required': 51711,
#  'command injection': 11238,
#  'injection remote': 30815,
#  'remote command': 51069,
#  'command execution': 11228,
#  'execution vulnerability': 21972,
#  'vulnerability trend': 67024,
#  'trend micro': 61852,
#  'micro email': 38522,
#  'email encryption': 20266,
#  'encryption gateway': 20603,
#  'gateway allow': 26141,
#  'remote attacker': 51059,
#  'execute arbitrary': 21697,
#  'arbitrary code': 4319,
#  'code vulnerable': 10941,
#  'vulnerable installation': 67154,
#  'installation launcherserver': 31203,
#  'launcherserver authentication': 34203,
#  'authentication required': 5850,
#  'required exploit': 51722,
#  'ibm': 28659,
#  'guardium': 27029,
#  'big': 6778,
#  'data': 15760,
#  'intelligence': 31599,
#  'sonarg': 57596,
#  'doe': 18938,
#  'properly': 48553,
#  'restrict': 52143,
#  'size': 56965,
#  'resource': 51875,
#  'requested': 51644,
#  'influenced': 30320,
#  'actor': 1306,
#  'weakness': 67434,
#  'consume': 12705,
#  'intended': 31621,
#  'force': 24884,
#  'ibm security': 28717,
#  'security guardium': 54570,
#  'guardium big': 27030,
#  'big data': 6790,
#  'data intelligence': 15874,
#  'intelligence sonarg': 31605,
#  'sonarg doe': 57597,
#  'doe properly': 18982,
#  'properly restrict': 48596,
#  'restrict size': 52152,
#  'size resource': 56993,
#  'resource requested': 51929,
#  'requested influenced': 51652,
#  'influenced actor': 30321,
#  'actor weakness': 1316,
#  'weakness used': 67441,
#  'used consume': 63853,
#  'consume resource': 12713,
#  'resource intended': 51906,
#  'intended ibm': 31634,
#  'ibm force': 28688,
#  'antivirus': 3518,
#  'driver': 19341,
#  'k7fwhlpr': 33382,
#  'sys': 59963,
#  'allows': 3064,
#  'denial': 16800,
#  'service': 55514,
#  'bsod': 7670,
#  'possibly': 46765,
#  'unspecified': 63018,
#  'validating': 65063,
#  'input': 30892,
#  'value': 65221,
#  'ioctl': 32197,
#  'antivirus driver': 3525,
#  'driver file': 19360,
#  'file k7fwhlpr': 23756,
#  'k7fwhlpr sys': 33383,
#  'sys allows': 59966,
#  'allows local': 3150,
#  'local user': 35840,
#  'user cause': 64085,
#  'cause denial': 8734,
#  'denial service': 16802,
#  'service bsod': 55548,
#  'bsod possibly': 7672,
#  'possibly unspecified': 46792,
#  'unspecified impact': 63022,
#  'impact validating': 29443,
#  'validating input': 65069,
#  'input value': 30994,
#  'value ioctl': 65271,
#  'huawei': 28520,
#  'smart': 57103,
#  'phone': 45266,
#  'emily': 20381,
#  'factory': 23075,
#  'reset': 51798,
#  'frp': 25480,
#  'bypass': 8024,
#  'performs': 44984,
#  'special': 57778,
#  'operation': 42356,
#  'guide': 27108,
#  'function': 25572,
#  'use': 63625,
#  'normally': 41032,
#  'huawei smart': 28531,
#  'smart phone': 57117,
#  'phone emily': 45280,
#  'emily software': 20384,
#  'software factory': 57449,
#  'factory reset': 23080,
#  'reset protection': 51813,
#  'protection frp': 48715,
#  'frp bypass': 25481,
#  'bypass vulnerability': 8112,
#  'attacker user': 5437,
#  'user smart': 64392,
#  'phone performs': 45293,
#  'performs special': 44992,
#  'special operation': 57791,
#  'operation guide': 42374,
#  'guide function': 27110,
#  'function attacker': 25591,
#  'attacker exploit': 5241,
#  'vulnerability bypass': 66471,
#  'bypass frp': 8065,
#  'frp function': 25482,
#  'function use': 25844,
#  'use phone': 63743,
#  'phone normally': 45290,
#  'insufficient': 31406,
#  'validation': 65075,
#  'external': 22929,
#  'handler': 27260,
#  'google': 26735,
#  'allowed': 2990,
#  'program': 48393,
#  'machine': 36600,
#  'crafted': 14093,
#  'html': 28255,
#  'page': 43440,
#  'insufficient data': 31416,
#  'data validation': 16009,
#  'validation external': 65123,
#  'external protocol': 22941,
#  'protocol handler': 48788,
#  'handler google': 27272,
#  'google chrome': 26737,
#  'chrome prior': 9844,
#  'prior allowed': 47367,
#  'allowed remote': 3010,
#  'attacker potentially': 5355,
#  'potentially execute': 46916,
#  'arbitrary program': 4373,
#  'program user': 48424,
#  'user machine': 64267,
#  'machine crafted': 36608,
#  'crafted html': 14186,
#  'html page': 28312,
#  'sdcms': 54239,
#  'php': 45339,
#  'app': 3798,
#  'themecontroller': 60845,
#  'check_bad': 9699,
#  'attempt': 5490,
#  'block': 7093,
#  'eval': 21404,
#  'prevent': 47177,
#  'preg_replace': 47093,
#  'calls': 8339,
#  'allowing': 3018,
#  'leveraging': 34749,
#  'template': 60576,
#  'discovered sdcms': 18395,
#  'sdcms php': 54241,
#  'php app': 45362,
#  'app admin': 3800,
#  'admin controller': 1710,
#  'controller themecontroller': 13457,
#  'themecontroller php': 60846,
#  'php check_bad': 45383,
#  'check_bad function': 9700,
#  'function attempt': 25592,
#  'attempt block': 5492,
#  'block certain': 7097,
#  'certain php': 9207,
#  'php function': 45445,
#  'function eval': 25645,
#  'eval doe': 21406,
#  'doe prevent': 18980,
#  'prevent use': 47194,
#  'use preg_replace': 63751,
#  'preg_replace calls': 47094,
#  'calls allowing': 8342,
#  'allowing user': 3062,
#  'user execute': 64169,
#  'code leveraging': 10822,
#  'leveraging access': 34751,
#  'access admin': 506,
#  'admin template': 1806,
#  'template management': 60591,
#  'xss': 69046,
#  'waimai': 67231,
#  'super': 59506,
#  'cms': 10621,
#  'fname': 24747,
#  'parameter': 43744,
#  'food': 24869,
#  'addsave': 1632,
#  'editsave': 20016,
#  'uri': 63394,
#  'xss exists': 69102,
#  'exists waimai': 22314,
#  'waimai super': 67232,
#  'super cms': 59509,
#  'cms fname': 10631,
#  'fname parameter': 24748,
#  'parameter admin': 43755,
#  'admin php': 1775,
#  'php food': 45439,
#  'food addsave': 24870,
#  'addsave admin': 1633,
#  'food editsave': 24872,
#  'editsave uri': 20017,
#  'hdf': 27598,
#  'hdf5': 27603,
#  'library': 34994,
#  'heap': 27700,
#  'based': 6470,
#  'buffer': 7733,
#  'read': 49833,
#  'h5vm_memcpyvv': 27177,
#  'discovered hdf': 18279,
#  'hdf hdf5': 27602,
#  'hdf5 library': 27605,
#  'library heap': 35027,
#  'heap based': 27704,
#  'based buffer': 6482,
#  'buffer read': 7783,
#  'read function': 49894,
#  'function h5vm_memcpyvv': 25679,
#  'multiple': 39815,
#  'cisco': 9932,
#  'unified': 62726,
#  'contact': 12745,
#  'center': 9047,
#  'express': 22781,
#  'ccx': 8987,
#  'unauthenticated': 62462,
#  'conduct': 11974,
#  'request': 51426,
#  'forgery': 24955,
#  'ids': 28936,
#  'cscvg70921': 15189,
#  'multiple vulnerability': 39875,
#  'vulnerability web': 67072,
#  'web based': 67475,
#  'based management': 6512,
#  'interface cisco': 31742,
#  'cisco unified': 10011,
#  'unified contact': 62733,
#  'contact center': 12748,
#  'center express': 9061,
#  'express unified': 22790,
#  'unified ccx': 62729,
#  'ccx allow': 8988,
#  'allow unauthenticated': 2974,
#  'unauthenticated remote': 62488,
#  'attacker conduct': 5176,
#  'conduct cross': 11982,
#  'site request': 56884,
#  'request forgery': 51502,
#  'forgery csrf': 24961,
#  'csrf attack': 15291,
#  'attack cisco': 4997,
#  'cisco ids': 9969,
#  'ids cscvg70921': 29032,
#  'plugin': 46091,
#  'aka': 2612,
#  'plugins': 46158,
#  'u3dbrowser': 62297,
#  'fpi': 25237,
#  'foxitreader': 25212,
#  'exe': 21626,
#  'foxit': 25205,
#  'reader': 50034,
#  'bounds': 7393,
#  'obtain': 41549,
#  'sensitive': 54894,
#  'information': 30346,
#  'sample': 53576,
#  'faulting': 23234,
#  'address': 1524,
#  'control': 13209,
#  'branch': 7453,
#  'selection': 54725,
#  'starting': 58444,
#  'pluginmain': 46156,
#  '0x000000000012dff5': 26,
#  'plugin aka': 46093,
#  'aka plugins': 2696,
#  'plugins u3dbrowser': 46179,
#  'u3dbrowser fpi': 62298,
#  'fpi foxitreader': 25238,
#  'foxitreader exe': 25213,
#  'exe foxit': 21635,
#  'foxit reader': 25209,
#  'reader allows': 50036,
#  'allows remote': 3179,
#  'attacker cause': 5163,
#  'service bounds': 55545,
#  'bounds read': 7403,
#  'read obtain': 49933,
#  'obtain sensitive': 41599,
#  'sensitive information': 54908,
#  'information sample': 30488,
#  'sample data': 53578,
#  'data faulting': 15843,
#  'faulting address': 23235,
#  'address control': 1550,
#  'control branch': 13228,
#  'branch selection': 7458,
#  'selection starting': 54728,
#  'starting u3dbrowser': 58458,
#  'u3dbrowser pluginmain': 62299,
#  'pluginmain 0x000000000012dff5': 46157,
#  'api': 3636,
#  'connect': 12373,
#  'limited': 35282,
#  'administrator': 1902,
#  'level': 34683,
#  'member': 37985,
#  'functionality': 25874,
#  'ibm api': 28663,
#  'api connect': 3664,
#  'connect allows': 12376,
#  'allows user': 3208,
#  'user limited': 64249,
#  'limited api': 35284,
#  'api administrator': 3643,
#  'administrator level': 1941,
#  'level access': 34684,
#  'access administrator': 508,
#  'access member': 673,
#  'member functionality': 37992,
#  'functionality ibm': 25902,
#  'disclose': 18024,
#  'interaction': 31666,
#  'target': 60220,
#  'visit': 66142,
#  'specific': 57805,
#  'channel': 9507,
#  'number': 41275,
#  'cdef': 8995,
#  'box': 7412,
#  'result': 52231,
#  'lack': 33978,
#  'proper': 48537,
#  'supplied': 59535,
#  'past': 44431,
#  'end': 20626,
#  'allocated': 2847,
#  'object': 41437,
#  'leverage': 34728,
#  'conjunction': 12363,
#  'context': 13101,
#  'current': 15405,
#  'process': 47926,
#  'zdi': 69414,
#  'vulnerability allows': 66431,
#  'attacker disclose': 5213,
#  'disclose sensitive': 18030,
#  'information vulnerable': 30535,
#  'installation foxit': 31198,
#  'reader user': 50043,
#  'user interaction': 64230,
#  'interaction required': 31680,
#  'vulnerability target': 67009,
#  'target visit': 60259,
#  'visit malicious': 66148,
#  'malicious page': 36974,
#  'page open': 43517,
#  'open malicious': 42092,
#  'malicious file': 36942,
#  'file specific': 23932,
#  'specific exists': 57823,
#  'exists channel': 22147,
#  'channel number': 9519,
#  'number member': 41311,
#  'member cdef': 37987,
#  'cdef box': 8996,
#  'box result': 7426,
#  'result lack': 52295,
#  'lack proper': 34004,
#  'proper validation': 48551,
#  'validation user': 65204,
#  'user supplied': 64412,
#  'supplied data': 59543,
#  'data result': 15956,
#  'result read': 52319,
#  'read past': 49942,
#  'past end': 44435,
#  'end allocated': 20627,
#  'allocated object': 2855,
#  'object attacker': 41444,
#  'attacker leverage': 5296,
#  'leverage conjunction': 34730,
#  'conjunction vulnerability': 12370,
#  'vulnerability execute': 66586,
#  'code context': 10748,
#  'context current': 13112,
#  'current process': 15415,
#  'process zdi': 48043,
#  'disclosure': 18045,
#  'mate': 37647,
#  'pro': 47854,
#  'smartphones': 57145,
#  'earlier': 19628,
#  'lon': 36319,
#  'view': 65893,
#  'photo': 45320,
#  'unlocking': 62883,
#  'screen': 54024,
#  'lock': 35958,
#  'successful': 59372,
#  'condition': 11872,
#  'information disclosure': 30398,
#  'disclosure vulnerability': 18122,
#  'vulnerability mate': 66767,
#  'mate pro': 37651,
#  'pro huawei': 47860,
#  'huawei smartphones': 28532,
#  'smartphones earlier': 57149,
#  'earlier lon': 19704,
#  'lon attacker': 36320,
#  'attacker view': 5441,
#  'view photo': 65936,
#  'photo series': 45325,
#  'series operation': 55098,
#  'operation unlocking': 42399,
#  'unlocking screen': 62884,
#  'screen lock': 54035,
#  'lock successful': 35970,
#  'successful exploit': 59381,
#  'exploit cause': 22450,
#  'cause information': 8760,
#  'disclosure condition': 18064,
#  'expressway': 22811,
#  'telepresence': 60537,
#  'video': 65852,
#  'server': 55143,
#  'vcs': 65493,
#  'authenticated': 5666,
#  'underlying': 62607,
#  'operating': 42317,
#  'content': 12990,
#  'upgrade': 63217,
#  'packages': 43265,
#  'uploading': 63338,
#  'archive': 4440,
#  'vulnerability administrative': 66418,
#  'administrative web': 1899,
#  'web interface': 67498,
#  'cisco expressway': 9959,
#  'expressway series': 22813,
#  'series cisco': 55070,
#  'cisco telepresence': 10006,
#  'telepresence video': 60541,
#  'video communication': 65858,
#  'communication server': 11500,
#  'server vcs': 55474,
#  'vcs allow': 65494,
#  'allow authenticated': 2907,
#  'authenticated remote': 5696,
#  'code user': 10932,
#  'user level': 64245,
#  'level privilege': 34711,
#  'privilege underlying': 47768,
#  'underlying operating': 62616,
#  'operating vulnerability': 42353,
#  'vulnerability insufficient': 66693,
#  'insufficient validation': 31445,
#  'validation content': 65109,
#  'content upgrade': 13083,
#  'upgrade packages': 63224,
#  'packages attacker': 43266,
#  'vulnerability uploading': 67042,
#  'uploading malicious': 63349,
#  'malicious archive': 36903,
#  'archive upgrade': 4454,
#  'upgrade page': 63225,
#  'page administrative': 43448,
#  'interface successful': 31825,
#  'exploit allow': 22443,
#  'feature': 23277,
#  'device': 17228,
#  'guard': 27013,
#  'incorrectly': 30134,
#  'validates': 65050,
#  'untrusted': 63050,
#  'windows': 68013,
#  'servers': 55493,
#  'security feature': 54564,
#  'feature bypass': 23287,
#  'bypass exists': 8059,
#  'exists device': 22168,
#  'device guard': 17319,
#  'guard incorrectly': 27022,
#  'incorrectly validates': 30154,
#  'validates untrusted': 65059,
#  'untrusted file': 63056,
#  'file aka': 23566,
#  'aka device': 2642,
#  'guard security': 27025,
#  'affect windows': 2247,
#  'windows server': 68103,
#  'server windows': 55484,
#  'windows windows': 68122,
#  'windows servers': 68104,
#  'ssrf': 58304,
#  'sap': 53689,
#  'central': 9089,
#  'launchpad': 34204,
#  'fiori': 24307,
#  'common': 11434,
#  'technique': 60449,
#  'determine': 17167,
#  'backend': 6296,
#  'server request': 55406,
#  'forgery ssrf': 24968,
#  'ssrf vulnerability': 58319,
#  'vulnerability sap': 66921,
#  'sap central': 53693,
#  'central management': 9097,
#  'management console': 37151,
#  'console launchpad': 12626,
#  'launchpad fiori': 34206,
#  'fiori launchpad': 24309,
#  'launchpad allow': 34205,
#  'allow malicious': 2947,
#  'malicious user': 37012,
#  'user use': 64437,
#  'use common': 63660,
#  'common technique': 11452,
#  'technique determine': 60452,
#  'determine port': 17176,
#  'port use': 46523,
#  'use backend': 63644,
#  ...}

# %%
import pandas as pd
reports = pd.read_excel('data/sec_issues_edit.xlsx')
reports = reports.loc[(reports['security']==1)]
reports['security'] = reports['security'].values.astype(bool)
reports['report'] = reports['report'].values.astype(str)
print('Manually labeled vulnerability dataset: '+ str(len(reports)))
predicted = pipe.predict(reports['report'])
vulns_common.print_vulns_metrics(reports['security'], predicted)
# Out:
# Manually labeled vulnerability dataset: 148
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         0
#            1       1.00      0.74      0.85       148
#
#    micro avg       0.74      0.74      0.74       148
#    macro avg       0.50      0.37      0.43       148
# weighted avg       1.00      0.74      0.85       148
#
# TN=0, FP=0, FN=38, TP=110
# C:\Users\ossi.jormakka\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
## How it finds from the learning set

# %%
print('Vulnerability learning dataset:'+str(len(vuln_descs)))
predicted = pipe.predict(vuln_descs)
vulns_common.print_vulns_metrics([1]*len(vuln_descs), predicted)
# Out:
# Vulnerability learning dataset:5823
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         0
#            1       1.00      0.79      0.88      5823
#
#    micro avg       0.79      0.79      0.79      5823
#    macro avg       0.50      0.39      0.44      5823
# weighted avg       1.00      0.79      0.88      5823
#
# TN=0, FP=0, FN=1251, TP=4572

# %%
print('Mixed dataset: '+ str(len(mixed)))
predicted = pipe.predict(mixed['report'])
vulns_common.print_vulns_metrics(mixed['security'], predicted)
# Out:
# Mixed dataset: 1148
#               precision    recall  f1-score   support
#
#           -1       0.95      0.69      0.80      1000
#            1       0.26      0.74      0.39       148
#
#    micro avg       0.70      0.70      0.70      1148
#    macro avg       0.61      0.72      0.59      1148
# weighted avg       0.86      0.70      0.75      1148
#
# TN=691, FP=309, FN=38, TP=110

# %%
## How much the method produces false alarms

# %%
vulns_common.print_classified_dataset('data/Ambari.csv', pipe)
vulns_common.print_classified_dataset('data/Camel.csv', pipe)
vulns_common.print_classified_dataset('data/Wicket.csv', pipe)
vulns_common.print_classified_dataset('data/Chromium.csv', pipe)
vulns_common.print_classified_dataset('data/Derby.csv', pipe)
# Out:
# Test on data/Ambari.csv. Rows: 1000
#               precision    recall  f1-score   support
#
#        False       0.98      0.81      0.88       971
#         True       0.05      0.34      0.09        29
#
#    micro avg       0.79      0.79      0.79      1000
#    macro avg       0.51      0.58      0.49      1000
# weighted avg       0.95      0.79      0.86      1000
#
# TN=783, FP=188, FN=19, TP=10
# Test on data/Camel.csv. Rows: 1000
#               precision    recall  f1-score   support
#
#        False       0.98      0.66      0.79       967
#         True       0.05      0.59      0.10        32
#
#    micro avg       0.66      0.66      0.66       999
#    macro avg       0.52      0.63      0.44       999
# weighted avg       0.95      0.66      0.77       999
#
# TN=637, FP=330, FN=13, TP=19
# Test on data/Wicket.csv. Rows: 1000
#               precision    recall  f1-score   support
#
#        False       0.99      0.62      0.76       990
#         True       0.01      0.50      0.03        10
#
#    micro avg       0.62      0.62      0.62      1000
#    macro avg       0.50      0.56      0.40      1000
# weighted avg       0.98      0.62      0.76      1000
#
# TN=616, FP=374, FN=5, TP=5
# Test on data/Chromium.csv. Rows: 1000
#               precision    recall  f1-score   support
#
#        False       1.00      0.79      0.88       996
#         True       0.01      0.75      0.03         4
#
#    micro avg       0.79      0.79      0.79      1000
#    macro avg       0.51      0.77      0.46      1000
# weighted avg       0.99      0.79      0.88      1000
#
# TN=789, FP=207, FN=1, TP=3
# Test on data/Derby.csv. Rows: 1000
#               precision    recall  f1-score   support
#
#        False       0.94      0.65      0.77       910
#         True       0.14      0.60      0.23        88
#
#    micro avg       0.65      0.65      0.65       998
#    macro avg       0.54      0.63      0.50       998
# weighted avg       0.87      0.65      0.72       998
#
# TN=591, FP=319, FN=35, TP=53

# %%
import pandas as pd

reports = pd.read_csv('data/Wicket.csv')
reports = vulns_common.preprocess_csv_data(reports)
sec_issues = reports.loc[(reports['security']==1)]
normal_bugs = reports.loc[(reports['security']==0)]
print('Security related issue:\n' + sec_issues.iloc[0]['report'] + '\n')
print('Normal bug report:\n' + normal_bugs.iloc[0]['report'])
# Out:
# Security related issue:
# IDataProvider-Overflow with size()   Hi I get an Integer-overflow with my Dataprovider (yeah  there are a couple of entries in the database). Is there a reason why size() and iterator( first  count ) are limited to Integer?Regards  &#8212; Jan.
#
# Normal bug report:
# open Modal Window without AjaxRequestTarget   Wicket 1.2.2 included a new Modal Window component. However  this component can only be used with a valid AjaxRequestTarget. It would be useful if Modal Windows could be opened programmatically at any time without an AjaxRequestTarget.

# %%
## find optimal oneclass svm hyperparameters

# %%
#from sklearn.model_selection import GridSearchCV
#cannot use GridSearchCv as fitting and predicting with a separate data
from sklearn.model_selection import ParameterGrid

#OneClassSVM hyperparameters in the pipeline
parameters = {'clf__kernel': ('linear', 'rbf'),#default rbf
              'clf__shrinking': (True, False),
              'clf__tol': (1e-5, 1e-6, 1e-7),
              'clf__nu': (0.1, 0.2, 0.5),#default 0.5
             }

for z in ParameterGrid(parameters):
    pipe.set_params(**z)
    pipe.fit(vuln_descs)
    predicted = pipe.predict(mixed['report'])
    score = roc_auc_score(y_true=mixed['security'], y_score=predicted, average='micro')
    print(str(score)+': '+str(z))
# Out:
# 0.7334054054054056: {'clf__kernel': 'linear', 'clf__nu': 0.1, 'clf__shrinking': True, 'clf__tol': 1e-05}
# 0.7334054054054056: {'clf__kernel': 'linear', 'clf__nu': 0.1, 'clf__shrinking': True, 'clf__tol': 1e-06}
# 0.7334054054054056: {'clf__kernel': 'linear', 'clf__nu': 0.1, 'clf__shrinking': True, 'clf__tol': 1e-07}
# 0.7334054054054056: {'clf__kernel': 'linear', 'clf__nu': 0.1, 'clf__shrinking': False, 'clf__tol': 1e-05}
# 0.7334054054054056: {'clf__kernel': 'linear', 'clf__nu': 0.1, 'clf__shrinking': False, 'clf__tol': 1e-06}
# 0.7334054054054056: {'clf__kernel': 'linear', 'clf__nu': 0.1, 'clf__shrinking': False, 'clf__tol': 1e-07}
# 0.7319864864864865: {'clf__kernel': 'linear', 'clf__nu': 0.2, 'clf__shrinking': True, 'clf__tol': 1e-05}
# 0.7319864864864865: {'clf__kernel': 'linear', 'clf__nu': 0.2, 'clf__shrinking': True, 'clf__tol': 1e-06}
# 0.7319864864864865: {'clf__kernel': 'linear', 'clf__nu': 0.2, 'clf__shrinking': True, 'clf__tol': 1e-07}
# 0.7319864864864865: {'clf__kernel': 'linear', 'clf__nu': 0.2, 'clf__shrinking': False, 'clf__tol': 1e-05}
# 0.7319864864864865: {'clf__kernel': 'linear', 'clf__nu': 0.2, 'clf__shrinking': False, 'clf__tol': 1e-06}
# 0.7319864864864865: {'clf__kernel': 'linear', 'clf__nu': 0.2, 'clf__shrinking': False, 'clf__tol': 1e-07}
# 0.6864594594594594: {'clf__kernel': 'linear', 'clf__nu': 0.5, 'clf__shrinking': True, 'clf__tol': 1e-05}
# 0.6864594594594594: {'clf__kernel': 'linear', 'clf__nu': 0.5, 'clf__shrinking': True, 'clf__tol': 1e-06}
# 0.6864594594594594: {'clf__kernel': 'linear', 'clf__nu': 0.5, 'clf__shrinking': True, 'clf__tol': 1e-07}
# 0.6864594594594594: {'clf__kernel': 'linear', 'clf__nu': 0.5, 'clf__shrinking': False, 'clf__tol': 1e-05}
# 0.6864594594594594: {'clf__kernel': 'linear', 'clf__nu': 0.5, 'clf__shrinking': False, 'clf__tol': 1e-06}
# 0.6864594594594594: {'clf__kernel': 'linear', 'clf__nu': 0.5, 'clf__shrinking': False, 'clf__tol': 1e-07}
# 0.7339054054054055: {'clf__kernel': 'rbf', 'clf__nu': 0.1, 'clf__shrinking': True, 'clf__tol': 1e-05}
# 0.7339054054054055: {'clf__kernel': 'rbf', 'clf__nu': 0.1, 'clf__shrinking': True, 'clf__tol': 1e-06}
# 0.7339054054054055: {'clf__kernel': 'rbf', 'clf__nu': 0.1, 'clf__shrinking': True, 'clf__tol': 1e-07}
# 0.7339054054054055: {'clf__kernel': 'rbf', 'clf__nu': 0.1, 'clf__shrinking': False, 'clf__tol': 1e-05}
# 0.7339054054054055: {'clf__kernel': 'rbf', 'clf__nu': 0.1, 'clf__shrinking': False, 'clf__tol': 1e-06}
# 0.7339054054054055: {'clf__kernel': 'rbf', 'clf__nu': 0.1, 'clf__shrinking': False, 'clf__tol': 1e-07}
# 0.7324864864864866: {'clf__kernel': 'rbf', 'clf__nu': 0.2, 'clf__shrinking': True, 'clf__tol': 1e-05}
# 0.7324864864864866: {'clf__kernel': 'rbf', 'clf__nu': 0.2, 'clf__shrinking': True, 'clf__tol': 1e-06}
# 0.7324864864864866: {'clf__kernel': 'rbf', 'clf__nu': 0.2, 'clf__shrinking': True, 'clf__tol': 1e-07}
# 0.7324864864864866: {'clf__kernel': 'rbf', 'clf__nu': 0.2, 'clf__shrinking': False, 'clf__tol': 1e-05}
# 0.7324864864864866: {'clf__kernel': 'rbf', 'clf__nu': 0.2, 'clf__shrinking': False, 'clf__tol': 1e-06}
# 0.7324864864864866: {'clf__kernel': 'rbf', 'clf__nu': 0.2, 'clf__shrinking': False, 'clf__tol': 1e-07}
# 0.6864594594594594: {'clf__kernel': 'rbf', 'clf__nu': 0.5, 'clf__shrinking': True, 'clf__tol': 1e-05}
# 0.6864594594594594: {'clf__kernel': 'rbf', 'clf__nu': 0.5, 'clf__shrinking': True, 'clf__tol': 1e-06}
# 0.6864594594594594: {'clf__kernel': 'rbf', 'clf__nu': 0.5, 'clf__shrinking': True, 'clf__tol': 1e-07}
# 0.6864594594594594: {'clf__kernel': 'rbf', 'clf__nu': 0.5, 'clf__shrinking': False, 'clf__tol': 1e-05}
# 0.6864594594594594: {'clf__kernel': 'rbf', 'clf__nu': 0.5, 'clf__shrinking': False, 'clf__tol': 1e-06}
# 0.6864594594594594: {'clf__kernel': 'rbf', 'clf__nu': 0.5, 'clf__shrinking': False, 'clf__tol': 1e-07}

# %%
## Find optimal dataset size to fit the classifier

# %%
sample_sizes = [100, 500, 1000, 2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000]

classifier =

final_results = []
for size in sample_sizes:
    print(str(size), end='')
    results = dict()
    for v in vectorizers:
        results[v.__class__.__name__] = 0.0 

    for n in range(10):#10-fold cross validation
        vuln_data = shuffle(nvd_vulns, n_samples=size)
        vuln_descs = []
        for d in vuln_data:
            vuln_descs.append(d[1])
        mixed = vulns_common.get_mixed_dataset(reports['report'], 1000)
    
        for v in vectorizers:
            pipe = Pipeline([('vect', v), ('clf', classifier)])
            pipe = pipe.fit(vuln_descs)
            predicted = pipe.predict(mixed['report'])
            #score = f1_score(y_true=mixed['security'], y_pred=predicted, average='micro')
            score = roc_auc_score(y_true=mixed['security'], y_score=predicted, average='micro')
            prev_score = results[v.__class__.__name__]
            results[v.__class__.__name__] = score + prev_score
            print('.', end='')

    for i, (key, value) in enumerate(results.items()):
        final_results.append([str(size), key, value/10])
        print('\n'+key + str(value/10))
    print('\n')

print('done')
# Out:
# 100............................................................
# CountVectorizer0.692558108108108
#
# StemmedCountVectorizer0.6974378378378379
#
# TfidfVectorizer0.5870418918918918
#
# StemmedTfidfVectorizer0.6090405405405404
#
# LemmaTfidfVectorizer0.5967527027027026
#
# LemmaCountVectorizer0.6865500000000001
#
#
# 500............................................................
# CountVectorizer0.6872054054054054
#
# StemmedCountVectorizer0.6837837837837838
#
# TfidfVectorizer0.6679527027027027
#
# StemmedTfidfVectorizer0.6827378378378378
#
# LemmaTfidfVectorizer0.6795202702702703
#
# LemmaCountVectorizer0.6817986486486488
#
#
# 1000............................................................
# CountVectorizer0.6774202702702702
#
# StemmedCountVectorizer0.6738837837837838
#
# TfidfVectorizer0.7076445945945947
#
# StemmedTfidfVectorizer0.6965148648648649
#
# LemmaTfidfVectorizer0.7103945945945945
#
# LemmaCountVectorizer0.6719013513513513
#
#
# 2000............................................................
# CountVectorizer0.6734500000000001
#
# StemmedCountVectorizer0.6789824324324323
#
# TfidfVectorizer0.7142540540540542
#
# StemmedTfidfVectorizer0.6983324324324325
#
# LemmaTfidfVectorizer0.7172162162162162
#
# LemmaCountVectorizer0.6697432432432433
#
#
# 4000............................................................
# CountVectorizer0.6723067567567569
#
# StemmedCountVectorizer0.6768486486486488
#
# TfidfVectorizer0.7210391891891892
#
# StemmedTfidfVectorizer0.6936783783783783
#
# LemmaTfidfVectorizer0.72315
#
# LemmaCountVectorizer0.6712783783783783
#
#
# 6000............................................................
# CountVectorizer0.6694067567567569
#
# StemmedCountVectorizer0.6778135135135136
#
# TfidfVectorizer0.722377027027027
#
# StemmedTfidfVectorizer0.6909621621621622
#
# LemmaTfidfVectorizer0.7247743243243244
#
# LemmaCountVectorizer0.6683891891891892
#
#
# 8000............................................................
# CountVectorizer0.6706216216216216
#
# StemmedCountVectorizer0.6756391891891892
#
# TfidfVectorizer0.7178472972972976
#
# StemmedTfidfVectorizer0.6917500000000001
#
# LemmaTfidfVectorizer0.7164797297297297
#
# LemmaCountVectorizer0.6751108108108108
#
#
# 10000............................................................
# CountVectorizer0.667408108108108
#
# StemmedCountVectorizer0.6762662162162163
#
# TfidfVectorizer0.7198243243243243
#
# StemmedTfidfVectorizer0.6919270270270272
#
# LemmaTfidfVectorizer0.718031081081081
#
# LemmaCountVectorizer0.6706581081081081
#
#
# 12000............................................................
# CountVectorizer0.671133783783784
#
# StemmedCountVectorizer0.676477027027027
#
# TfidfVectorizer0.7167945945945945
#
# StemmedTfidfVectorizer0.6891472972972974
#
# LemmaTfidfVectorizer0.7166527027027028
#
# LemmaCountVectorizer0.6736851351351352
#
#
# 14000............................................................
# CountVectorizer0.6644716216216218
#
# StemmedCountVectorizer0.676254054054054
#
# TfidfVectorizer0.7124648648648649
#
# StemmedTfidfVectorizer0.6908972972972974
#
# LemmaTfidfVectorizer0.71395
#
# LemmaCountVectorizer0.6682851351351351
#
#
# 16000............................................................
# CountVectorizer0.6689351351351351
#
# StemmedCountVectorizer0.6788540540540541
#
# TfidfVectorizer0.712264864864865
#
# StemmedTfidfVectorizer0.6971662162162162
#
# LemmaTfidfVectorizer0.7139621621621621
#
# LemmaCountVectorizer0.6753635135135135
#
#
# 18000............................................................
# CountVectorizer0.6642837837837837
#
# StemmedCountVectorizer0.6746054054054055
#
# TfidfVectorizer0.7113135135135136
#
# StemmedTfidfVectorizer0.6974675675675676
#
# LemmaTfidfVectorizer0.7160013513513512
#
# LemmaCountVectorizer0.6732256756756756
#
#
# done
